# %%
import time, os
from pymystem3 import Mystem
import re, json, requests, numpy as np
from yaml import safe_load
from sklearn.feature_extraction.text import CountVectorizer
from scipy.cluster.hierarchy import linkage, fcluster
from datetime import datetime

# %%
def string_negative_keywords(txt_file):

    '''
    Получает название файла в рабочем каталоге
    Возвращает строку минус слов
    '''

    f = open(txt_file, 'r')#, encoding='utf-8')
    list_neg = set([re.sub(r'[\[\]"\ufeff]', '', line.strip()) for line in f])
    list_of_negative = []
    for keyword in list_neg:
        print(keyword)
        if len(keyword.split()) > 1:
            list_of_negative.append('-({})'.format(keyword))

        else:
            list_of_negative.append('-{}'.format(keyword))
    f.close()
    print(' '.join(list_of_negative))
    print(len(' '.join(list_of_negative)))
    return ' '.join(list_of_negative)


def txt_to_lists_for_wordstat_reports(txt_file):
    '''
    На вход подается текстовый файл с масками запросов. Каждая маска на отдельной строке
    Возвращает список списков масок по 10 масок - ограничение Yandex Direct API
    Списки отсортированы по убыванию количества слов в запросе
    Если в файле более 1000 масок - они отсекаются
    '''
    f = open(txt_file, 'r')
    temp_keyword_list = []
    new_list = []
    main_iterator = 1
    temp_iterator = 1

    for line in f:
        keyword_base = re.sub(r'[\[\]"+\ufeff]', '',line.strip())
        keyword_base = re.sub(r'[-,./\\#@%&^"\']', ' ', keyword_base)
        temp_keyword_list.append(keyword_base)
        temp_keyword_list.sort(key=lambda x: len(x.split()), reverse=False)
        if len(temp_keyword_list) == 1000:
            break
    f.close()
    basic_keyword_list = []
    for keyword in temp_keyword_list:
        print(keyword)
        new_list.append(keyword)
        if main_iterator == 10:  # На отладке берем 3 запроса
            basic_keyword_list.append(new_list)
            new_list = []
            temp_iterator += 1
            main_iterator = 1

            continue
        if temp_iterator == len(temp_keyword_list):
            basic_keyword_list.append(new_list)
            new_list = []
            temp_iterator = 0

        main_iterator += 1
        temp_iterator += 1

    return basic_keyword_list


def createNewWordstatReport(basic_keyword_list, negative_kw, yandex_token, api_url, proxy, geo='' ):
    '''
    Формируем новый отчет Yandex Wordstat
    '''

    basic_keywords = []
    for keyword in basic_keyword_list:
        new_word = '{} {}'.format(keyword, negative_kw)
        basic_keywords.append(new_word)

    geo = list(geo)

    data = {
        # указываем метод вордстат, с которым работаем, в данном случае - создаем отчет
        'method': 'CreateNewWordstatReport',
        # задаем входные параметры; у каждого метода они свои
        'token': yandex_token,
        'param': {
            # Указываем не более 10 фраз через запятую
            'Phrases': basic_keywords,
            # Указываем нужный регион, если не указали - Все регионы
            'GeoID': geo
        }}
    encoded_data = json.dumps(data, ensure_ascii=False).encode('utf-8')
    print(encoded_data)
    # создаем отчет
    requests.post(api_url, data=encoded_data, proxies=proxy)  # Если возвращает ошибку добавить аргумент proxies=proxy)


def getWordstatReportIdList(yandex_token, api_url, proxy):
    '''
    Возвращает список отчетов
    Структура списка [{'ReportID': 1873637, 'StatusReport': 'Done'}]
    '''
    report_data = {
        'token': yandex_token,
        'method': 'GetWordstatReportList'
    }
    report_list_encoded_data = json.dumps(report_data,
                                          ensure_ascii=False).encode('utf-8')

    return requests.post(api_url,
                         data=report_list_encoded_data, proxies=proxy).json()['data']


def deleteWordstatReport(yandex_token, api_url, report_id, proxy):
    '''
    Удаляет готовый отчет
    '''
    report_for_delete_data = {
        "method": "DeleteWordstatReport",
        "param": report_id,
        "token": yandex_token
    }
    encoded_data = json.dumps(report_for_delete_data,
                              ensure_ascii=False).encode('utf-8')
    r = requests.post(api_url, data=encoded_data, proxies=proxy)
    return r.json()['data']


def getWordstatReport(yandex_token, api_url, report_id, proxy):
    '''
    Функция возвращает отчет
    '''
    report_params = {
        'method': 'GetWordstatReport',
        'param': report_id,
        'token': yandex_token
    }
    report_encoded_data = json.dumps(report_params, ensure_ascii=False).encode('utf-8')
    # получаем отчет
    return requests.post(api_url, data=report_encoded_data, proxies=proxy).json()


def wordstatReadyReport(yandex_token, api_url, proxy):
    '''
    Получаем словарь с запросами
    '''
    time.sleep(5)
    reportList = getWordstatReportIdList(yandex_token, api_url, proxy)
    print(reportList)
    main_wordstat_report = {'data': []}
    for report_ in reportList:
        if report_["StatusReport"] == 'Done':
            # получаем отчет
            wordstat_report = getWordstatReport(yandex_token, api_url, report_["ReportID"], proxy)
            # удаляем отчет в Яндекс
            deleteWordstatReport(yandex_token, api_url, report_["ReportID"], proxy)
        elif report_["StatusReport"] == 'Failed':
            # удаляем отчет
            deleteWordstatReport(yandex_token, api_url, report_["ReportID"], proxy)
            continue
        else:
            time.sleep(5)
            if report_["StatusReport"] == 'Done':
                # запрашиваем статус отчета
                wordstat_report = getWordstatReport(yandex_token, api_url, report_["ReportID"], proxy)
                deleteWordstatReport(yandex_token, api_url, report_["ReportID"], proxy)
            else:
                deleteWordstatReport(yandex_token, api_url, report_["ReportID"], proxy)
        try:
            main_wordstat_report['data'].extend(wordstat_report['data'])
        except (KeyError, UnboundLocalError):
            continue
    return main_wordstat_report


def report_descriptor(reportDict):
    '''
    Функция лемматизирует ключевые слова и возвращает словарь с ключом = базовому слову
    Значения каждого слова словаря - список словарей структуры "ключевое слово": частота
    '''

    m = Mystem()
    keyword_dict = {}
    KW_list = []
    lemma_without_negative_word_regex = re.compile(r'^([A-ZА-Яа-яa-z\s\d+]*)\s-')
    for lemma_report in reportDict['data']:
        Started = True
        for report_dict in lemma_report['SearchedWith']:
            try:
                if Started:
                    Started = False
                    lemma_test = report_dict['Phrase']

                    lemma_search = lemma_without_negative_word_regex.search(lemma_test)
                    lemma_word = lemma_search.group(1)
                    print(lemma_word)
                    keyword_dict.setdefault(re.sub(r'\+', '', lemma_word), [])
                    continue
                word = report_dict['Phrase'].lower()
                word_show = report_dict['Shows']
                word = re.sub(r'\+', '', word)
                print(word)
                lemmas = m.lemmatize(word)
                # удаляем предлоги из леммы
                '''for part_of_speech in m.analyze(word):
                    # может быть обращение к словарю только включающему text
                    try:
                        if part_of_speech['analysis'] != []:
                            if part_of_speech['analysis'][0]['gr'] == 'PR=':
                                lemmas.remove(lemmas[lemmas.index(part_of_speech['text'])])
                    except KeyError:
                        continue'''

                for i in ['и', ' ', ',', '.', '\n', '+']:
                    while i in lemmas:
                        lemmas.remove(i)
                lemmas.sort()
                # приводим странные леммы
                if 'ипать' in lemmas:
                    lemmas[lemmas.index('ипать')] = 'ип'
                if 'банка' in lemmas:
                    lemmas[lemmas.index('банка')] = 'банк'
                if 'усна' in lemmas:
                    lemmas[lemmas.index('усна')] = 'усн'
                if 'юла' in lemmas:
                    lemmas[lemmas.index('юла')] = 'юл'

                # получаем готовое условие показа
                new_word = ' '.join(lemmas)
                if new_word in KW_list:
                    continue
                KW_list.append(new_word)
                new_word_dict = {new_word: word_show}
                keyword_dict[lemma_word].append(new_word_dict)
                if keyword_dict[lemma_word] == []:
                    keyword_dict.pop(lemma_word)
            except AttributeError:
                print('AttributeError')
    return keyword_dict, KW_list

# %%
API_URL = 'https://api-sandbox.direct.yandex.ru/live/v4/json/'

config_file = open('config_new.yam', mode = 'r', encoding = 'utf-8')
config = safe_load(config_file)
config_file.close()
token = config['access_token_ya_direkt']
proxy = {'http': config['proxy1'],
         'https': config['proxy2']}
# Минус слова
negativeKeywords = 'negative_kw.txt'
# Создаем строку минус слов
negative = string_negative_keywords(negativeKeywords)
# Маски запросов для отчетов
mask_txt = 'keywords.txt'
masks_lists = txt_to_lists_for_wordstat_reports(mask_txt)

# цикл по вложенным спискам
Started = True
for masks_list in masks_lists:
    createNewWordstatReport(masks_list, negative, token, API_URL, proxy, geo='43')
    if Started:
        keyword_dict = wordstatReadyReport(token, API_URL, proxy)
        Started = False
        continue
    keyword_dict['data'].extend(wordstatReadyReport(token, API_URL, proxy)['data'])

kw_Dict1, kw_list1 = report_descriptor(keyword_dict)
# Out:
# водитель
# челябинск
# эскорт
# уренгой
# ежедневная
# монтажные
# удалить
# выполнение
# нефтехим
# на !час
# !время
# зеленодольск
# стриптиз
# массажер
# место
# удаленная
# бывшая
# год
# класс
# сварщик
# суть
# детская
# уфсин
# образцы
# дипломный
# оэз
# учитель
# горничная
# смоленск
# ремонт
# математик
# хостес
# такси
# екатеринбург
# сосать
# смысл
# банкомат
# воронеж
# доу
# челны
# адрес
# трахать
# инженер
# история
# иваново
# курсовая
# строительство
# диплом
# график
# нижнекамск
# воспитатель
# грузчик
# выполним
# охрана
# москва
# опыт
# !часы
# реферат
# строитель
# библиотека
# принцип
# контрольная
# физик
# бригада
# мвд
# удаленка
# иркутск
# порно
# цена
# массаж
# стройка
# вахта
# скачать
# уф
# мерлен
# член
# режим
# секс
# алабуга
# школа
# охранник
# бригадир
# характер
# -водитель -челябинск -эскорт -уренгой -ежедневная -монтажные -удалить -выполнение -нефтехим -(на !час) -!время -зеленодольск -стриптиз -массажер -место -удаленная -бывшая -год -класс -сварщик -суть -детская -уфсин -образцы -дипломный -оэз -учитель -горничная -смоленск -ремонт -математик -хостес -такси -екатеринбург -сосать -смысл -банкомат -воронеж -доу -челны -адрес -трахать -инженер -история -иваново -курсовая -строительство -диплом -график -нижнекамск -воспитатель -грузчик -выполним -охрана -москва -опыт -!часы -реферат -строитель -библиотека -принцип -контрольная -физик -бригада -мвд -удаленка -иркутск -порно -цена -массаж -стройка -вахта -скачать -уф -мерлен -член -режим -секс -алабуга -школа -охранник -бригадир -характер
# работа аквапарка в казани
# работа сегодня казань
# работа м казани
# работа казань проектирование
# работа город казань
# казань работа без
# казань работа рынков
# татарстан казань работа
# работа в г казани
# найду работу казань
# работа ру казань
# работа казань официально
# работа зоопарка в казани
# работа по договору казань
# работа в казани для женщин
# работа казань центр
# работа для мужчин в казани
# работа в казани с проживанием
# работа мфц казань
# работа в казани 12
# найти работу в казани
# авито работа казань вакансии
# работа в казани республики татарстан
# новая работа казань
# работа 7 казань
# почему казани на станции выполняется маневровая работа
# работа в магазине казань
# работа казань официальный сайт
# ищу работу в казани
# работа в казани отзывы
# ручная работа казань
# работа музеев в казани
# работа кафе казань
# работа леруа казань
# казань работа группа
# работа в казани 2 2
# работа кремля в казани
# работа на дому казань
# социальная работа казань
# работа в вузах казани
# работа победа казань
# работа в компаниях казани
# работа категории в казань
# работа казани в области
# устроиться на работу в казани
# работа бухгалтером в казани
# работа с дорогой в казани
# работа казань ул
# хх казань работа
# сайт работа в казани
# работа в банке казань
# работа метро в казани
# работа 3 3 казань
# авито казань работа от прямых работодателей
# х х работа казань
# работа ресторанов в казани
# авито казань работа от работодателя
# работа аквапарка в казани ривьера
# работа вахтовая казань
# работа казань тц
# авито казань работа с проживанием
# хх ру казань работа
# гос работа казань
# работа казани бухгалтером мусульманке
# авто работа казань
# работа ч казани
# яндекс работа казань
# работа налоговой казань
# работа бахетле казань
# работа женщинам казань вакансии
# работа рынка тура казань
# казань работа центрального рынка
# работа туры в казани
# работа в храме казань
# казань экспресс работа
# вакансии мужчинам казань работа
# казань работа 1 2
# свежая работа для женщин казань
# работа гибдд казань
# работа машинист казань
# работа категории е в казани
# авито казань работа вакансии работодатель
# работа ру казань вакансии
# работа в казани свежие вакансии для женщин
# работа 116 казань
# работа автобус в казани
# авито работа казань вакансии от прямых
# поиск работы в казани
# авито казань работа вакансии от прямых работодателей
# работа нужна казань
# пэк казань работа
# прайс лист на сантехнические работы казань
# сантехнические работы казань
# работа казань 2019
# работа в россии казань
# работа ru казань
# работа начальник казани
# сантехнические работы казань прайс
# казань работа погрузчика
# работа почты россии казань
# расценки работ казани
# работа в пятерочке казань
# работа казань добро
# работа медсестрой в казани
# работа колеса обозрения в казани
# вайлдберриз работа казань
# добрая столовая казань работа
# транспорт работа казань
# работа алтын казань
# казань работа обувь
# работа втб казань
# парк кырлай казань работа
# работа няней в казани
# работа на машине казань
# работа казань 18
# работа в казани свежие вакансии для мужчин
# работа паспортного стола казань
# работа на автомобиле казань
# дорожные работы казань
# работа в казани 5 5
# работа 16 казань
# работа поваром в казани
# работа в магните казань
# нотариус казань работа
# сдэк работа казань
# работа казань 14
# работа на тэцевской казань
# бесплатно работа казань
# обувь ручной работы казань
# казань арена работа
# wildberries работа казань
# работа в сбербанке казань
# работа казань резюме
# парк горького казань работа
# казань работа вакансии от прямых работодателей мужчинам
# государственная работа казань
# работа казани приволжского района
# декатлон работа казань
# работа 4 4 в казани
# работа казань ак барс
# работа в диди казань
# работа врачом в казани
# проектные работы казань
# работа уборщицей в казани
# альфа банк работа казань
# казани устройства на работу
# работа мечетей в казани
# работа разнорабочего в казани
# ночная работа казань
# работа бизнес казань
# строительные работы в казани
# работа автомаляром в казани
# работы казань кольцо
# отделочные работы казань
# работа вахтовым методом в казани
# работа ру в казани бухгалтером
# работа сейчас казань
# работа казань метрополитен
# загс казань работа
# работа каменщика в казани
# работа казань авиастроительный
# купить работы казань
# работа в казани производство
# нн работа казань
# работа электриком в казани
# работа вечером казань
# мегастрой работа казань
# ак барс банк казань работа
# работа мусульманкам в казани
# авито работа казань автомаляр
# работа в салоне красоты казань
# работа почты в казани
# работа в казани с проживанием для мужчин
# работа гаи казань
# казань работа вакансии на сегодня
# работа ру казань свежие
# hh работа в казани
# работа в казани стоимость
# работа оби казань
# казань работа образование
# работа в воскресенье казань
# работа спортмастер казань
# работа кат е казань
# работа рабочим в казани
# работа на заводе в казани
# казань работа женщинам от прямых работодателей
# работа в казани для студентов
# казань работа семья
# работа в казани с жильем
# работа агропарк казань
# работа мастером казань
# ооо работа казань
# перспектива казань работа
# работа в казани категория д
# работа казань клубы
# работа участков голосования 1 июля 2020 казань
# работа в парках казани
# хорошую работу в казани
# работа в казани продавец
# работа парк хауса казань
# авито казань работа от прямых работодателей свежие
# работа музеев в казани в августе 2020
# казань расписание работы
# казань работа специалист
# работа высокая казань
# работа в икеа казань
# работа тандем казань
# казань работа квартира
# работа в ржд казань
# работа в офисе казань
# работа ресторанов в казани коронавирус
# работа московский район казань
# земляные работы казань
# работа казань межгород
# работа в казани с проживанием для иногородних
# работа тендер казань
# хантер казань работа
# работа косметика казань
# работа иногородним в казани
# работа казань английский
# работа казань театры
# работа в казани 15 15
# работа потолки натяжные казань
# казань работа сантехника
# мтс работа казань
# работа в пятерочке казань отзывы сотрудников
# работа н казани
# казань работа с предоставлением жилья
# казань работа кафе ресторан
# лента работ казань
# медосмотр на работу казань
# работа в коврове свежие вакансии казань
# работа в казани с предоставлением
# фасадные работы казань
# бургер кинг казань работа
# казань работа с проживанием от прямых работодателей
# работа сантехник казань
# работа в мчс казань
# работа восстания казань
# казань работа вьетнамского рынка
# зарплата работа в казани
# работа экскаватор казани
# авито работа категория е казань
# работа гостиницы казань
# работа пятерочка казань отзывы
# поиск работы в казани вакансии
# ищу работу в казани каменщиком
# казань объявления работа
# казань работа с проживанием от прямых
# работа слесарем казань
# работа кондуктором в казани
# работа в макдональдс казань
# работа форекс казань
# работа карусель казань
# магазин пятерочка работа казани
# сварочные работы казань
# работа кфу казань
# частный работа казань
# работы вакансии казань погрузчики
# работа на день казань
# работа казань окна
# работа в казани видео
# работа для девушек в казани
# работа дальнобойщиком в казани
# работа поликлиник казань
# работа магнит косметик казань
# работа на дому казань вакансии
# казань работа вакансии студентам
# заказать работу казань
# работа в казани с проживанием для женщин
# прайс на отделочные работы в казани
# работа на грузовых в казани
# работа химиком казань
# работа транспортных компаний казань
# работа на грузовом автомобиле казань
# монолитные работы казань
# работа максидом казань
# хх казань работа вакансии
# работа в казани после армии
# работа монтажником в казани
# иннополис казань работа
# хх казань работа от прямых работодателей
# работа от прямых работодателей казань склад
# работа слесарем в казани от прямых работодателей
# работа от прямых работодателей казань медсестрой
# работа няней в казани от прямых работодателей
# найти работу прямого работодателя казань
# работа юристом в казани от прямых работодателей
# hh казань работа от прямых работодателей
# поиск работы в казани от прямых работодателей
# работа в казани от прямых
# работа в казани от прямых
# работа в казани от прямых работодателей
# работа казань вакансии от прямых
# работа казань вакансии от прямых работодателей
# работа казань свежие вакансии от прямых
# работа казани от прямых работодателей свежие вакансии
# работа в казани от прямых работодателей свежие
# авито казань работа от прямых работодателей
# авито работа казань вакансии от прямых
# авито казань работа вакансии от прямых работодателей
# казань работа вакансии от прямых работодателей мужчинам
# казань работа женщинам от прямых работодателей
# авито казань работа от прямых работодателей свежие
# казань работа с проживанием от прямых работодателей
# казань работа с проживанием от прямых
# казань работа вакансии от прямых работодателей женщинам
# работа ру казань от прямых работодателей
# работа в казани бухгалтером от прямых
# работа в казани бухгалтером от прямых работодателей
# хх казань работа от прямых работодателей
# хх работа казань вакансии от прямых
# работа от прямых работодателей казань склад
# работа слесарем в казани от прямых работодателей
# поиск работы в казани от прямых
# работа от прямых работодателей казань медсестрой
# работа няней в казани от прямых работодателей
# найти работу в казани от прямых
# работа в казани от прямых няня
# найти работу прямого работодателя казань
# работа медсестры в казани от прямых
# работа юристом в казани от прямых работодателей
# hh ru казань работа от прямых
# работа в казани от прямых на авито
# hh казань работа от прямых работодателей
# работа в казани от прямых юрист
# hh казань работа от прямых
# поиск работы в казани от прямых работодателей

# %%
kw_Dict1
# Out:
# {'вакансии казань': [{'вакансия казань': 3317},
#   {'вакансия казань работа': 568},
#   {'вакансия казань свежий': 319},
#   {'вакансия казань работодатель': 293},
#   {'вакансия казань от прямой': 283},
#   {'вакансия казань казань от прямой работодатель': 279},
#   {'в вакансия казань работа свежий': 232},
#   {'вакансия казань от прямой работа': 185},
#   {'вакансия казань от прямой работа работодатель': 184},
#   {'вакансия казань работодатель свежий': 177},
#   {'вакансия казань от прямой свежий': 171},
#   {'вакансия казань от прямой работа свежий': 153},
#   {'вакансия казань от прямой работа работодатель свежий': 152},
#   {'в вакансия казань от прямой работодатель свежий': 147},
#   {'авито вакансия казань': 145},
#   {'вакансия казань сайт': 88},
#   {'вакансия казань официальный сайт': 85},
#   {'вакансия завод казань': 64},
#   {'авито вакансия казань работа': 50},
#   {'hh вакансия казань': 44},
#   {'бухгалтер вакансия казань': 36},
#   {'вакансия казань склад': 35},
#   {'вакансия казань ооо': 35},
#   {'вакансия казань ру': 34},
#   {'без вакансия казань': 34},
#   {'вайлдберриз вакансия казань': 33},
#   {'вакансия казань мужчина': 32},
#   {'вакансия г казань': 32},
#   {'вакансия казань менеджер': 31},
#   {'банк вакансия казань': 31},
#   {'вакансия казань хедхантер': 30},
#   {'вакансия дорога казань': 28},
#   {'вакансия казань ржд': 27},
#   {'в вакансия для женщина казань': 27},
#   {'авито вакансия казань от прямой работодатель': 27},
#   {'авито вакансия казань работодатель': 27},
#   {'вакансия казань нн': 26},
#   {'вакансия казань центр': 26},
#   {'вакансия казань магазин': 26},
#   {'вакансия казань помощник': 25},
#   {'вакансия е казань категория': 24},
#   {'вакансия газпром казань': 24},
#   {'вакансия казань сиделка': 23},
#   {'вакансия директор казань': 22},
#   {'2 2 вакансия казань': 22},
#   {'вакансия женщина казань работа': 21},
#   {'hh ru вакансия казань': 21},
#   {'вакансия казань руководитель': 21},
#   {'вакансия казань мужчина работа': 21},
#   {'вакансия казань начальник': 21},
#   {'вакансия казань технолог': 20},
#   {'вакансия казань машинист': 20},
#   {'в вакансия врач казань': 20},
#   {'вакансия город казань': 20},
#   {'вакансия казань транспортный': 20},
#   {'вакансия иннополис казань': 20},
#   {'авито вакансия казань работа работодатель': 19},
#   {'вакансия казань работа ру': 19},
#   {'вакансия казань оргсинтез': 19},
#   {'администратор вакансия казань': 19},
#   {'в вакансия для женщина казань работа свежий': 19},
#   {'авито вакансия казань от прямой работа': 19},
#   {'вакансия женщина казань свежий': 19},
#   {'авито вакансия казань от прямой работа работодатель': 19},
#   {'вакансия казань телематика': 18},
#   {'вакансия казань проживание с': 18},
#   {'вакансия казань психолог': 18},
#   {'вакансия валберис казань': 17},
#   {'вакансия казань продавец': 17},
#   {'в вакансия для казань мужчина свежий': 17},
#   {'в вакансия казань сфера': 17},
#   {'вакансия казань фармацевт': 16},
#   {'вакансия казань медицинский': 16},
#   {'вакансия казань техник': 16},
#   {'авито вакансия казань на свежий': 16},
#   {'авито вакансия казань от прямой свежий': 15},
#   {'вакансия занятость казань центр': 15},
#   {'вакансия казань уборщица': 15},
#   {'аэропорт вакансия казань': 15},
#   {'вакансия казань мастер': 15},
#   {'в вакансия казань медсестра': 15},
#   {'вакансия кадры казань отдел': 15},
#   {'вакансия казань татнефть': 15},
#   {'в вакансия для казань мужчина работа свежий': 15},
#   {'вакансия казань механик': 15},
#   {'авито вакансия казань от работодатель свежий': 14},
#   {'hh вакансия казань от прямой': 14},
#   {'авито вакансия казань от прямой работодатель свежий': 14},
#   {'в вакансия казань компания': 14},
#   {'вакансия казань чоп': 13},
#   {'вакансия казань медработник': 13},
#   {'вакансия казань монтажник': 13},
#   {'вакансия казань механик от прямой работодатель': 13},
#   {'вакансия казань механик по транспорт': 13},
#   {'вакансия казань юрист': 13},
#   {'вакансия казань строительный': 13},
#   {'hh вакансия казань от прямой работодатель': 13},
#   {'hh вакансия казань от работодатель': 13},
#   {'вакансия казань мужчина от прямой работа работодатель': 13},
#   {'вакансия казань мадоу': 12},
#   {'вакансия казань цветок': 12},
#   {'вакансия казань производство': 12},
#   {'вакансия казань пятерочка': 12},
#   {'вакансия казань программист': 12},
#   {'вакансия казань медосмотр медработник по предрейсовый': 12},
#   {'вакансия казань туризм': 11},
#   {'вакансия казань продажа': 11},
#   {'вакансия казань озон': 11},
#   {'вакансия казань ркб': 11},
#   {'вакансия домработница казань': 11},
#   {'вакансия казань фикс': 11},
#   {'вакансия для казань студент': 11},
#   {'вакансия казань стоматолог': 11},
#   {'вакансия казань прайс фикс': 10},
#   {'вакансия казань слесарь': 10},
#   {'бесплатный вакансия казань': 10},
#   {'вакансия казань м': 10},
#   {'вакансия казань на работа сегодня': 10},
#   {'вакансия казань леруа': 10},
#   {'вакансия казань клиника': 10},
#   {'3 3 вакансия казань': 10},
#   {'вакансия казань оргсинтез официальный сайт': 10},
#   {'вакансия казань оргсинтез сайт': 10},
#   {'вакансия казань рычаг': 10},
#   {'вакансия казань культура': 10},
#   {'вакансия казань метро': 10},
#   {'вакансия казань управление': 10},
#   {'вакансия казань менеджер по продажа': 9},
#   {'вакансия казань хх': 9},
#   {'вакансия казань компания строительный': 9},
#   {'вакансия казань педиатр': 9},
#   {'вакансия казань ру хх': 9},
#   {'вакансия казань хантер': 9},
#   {'вакансия казань организатор': 9},
#   {'вакансия ветеринарный казань': 9},
#   {'вакансия казань элекон': 9},
#   {'вакансия гинеколог казань': 9},
#   {'в вакансия казань сегодня': 9},
#   {'вакансия казань фельдшер': 9},
#   {'hh ru вакансия казань от прямой': 8},
#   {'вакансия казань организатор педагог': 8},
#   {'вакансия казань находить': 8},
#   {'вакансия казань ресторан': 8},
#   {'вакансия казань логопед': 8},
#   {'в вакансия казань ковров работа свежий': 8},
#   {'автобус вакансия казань': 8},
#   {'безопасность вакансия казань': 8},
#   {'вакансия казань образование': 8},
#   {'вакансия казань яндекс': 8},
#   {'вакансия казань новый савиновский': 8},
#   {'вакансия казань перекресток': 8},
#   {'вакансия казань провизор': 8},
#   {'вакансия казань компания транспортный': 8},
#   {'вакансия дизайнер казань': 8},
#   {'вакансия казань начальник отдел': 8},
#   {'вакансия казань поиск': 8},
#   {'в вакансия делопроизводитель казань': 8},
#   {'вакансия казань погрузчик': 8},
#   {'вакансия казань экспресс': 8},
#   {'в вакансия казань поиск работа': 8},
#   {'вакансия казань новый район савиновский': 8},
#   {'hh ru вакансия казань от прямой работодатель': 7},
#   {'в вакансия казань стропальщик': 7},
#   {'вакансия казань труд': 7},
#   {'вакансия казань мчс': 7},
#   {'вакансия казань магнит': 7},
#   {'вакансия казань энергетика': 7},
#   {'в вакансия казань пансионат сиделка': 7},
#   {'вакансия казань погрузчик работа': 7},
#   {'вакансия казань машинист электропоезд': 7},
#   {'вакансия казань свежий хедхантер': 7},
#   {'вакансия жби казань': 7},
#   {'вакансия казань работник': 7},
#   {'вакансия е казань свежий': 7},
#   {'вакансия диспетчер казань': 7},
#   {'автосфера вакансия казань': 7},
#   {'в вайлдберриз вакансия казань склад': 7},
#   {'вакансия казань патп': 7},
#   {'вакансия икеа казань': 7},
#   {'вакансия дом казань на работа': 7},
#   {'вакансия дом казань на': 7},
#   {'вакансия казань работа студент': 7},
#   {'вакансия врач казань педиатр': 7},
#   {'вакансия казань терапевт': 7},
#   {'без вакансия казань посредник': 7},
#   {'вакансия казань нн ру': 7},
#   {'вакансия казань размещать': 7},
#   {'вакансия вахтовый казань метод': 7},
#   {'вакансия занятость казань официальный сайт центр': 6},
#   {'вакансия казань работа хх': 6},
#   {'вакансия казань фссп': 6},
#   {'в вакансия казань медсестра работа': 6},
#   {'вакансия казань находить работа': 6},
#   {'вакансия занятость казань сайт центр': 6},
#   {'вакансия дом кадры казань': 6},
#   {'вакансия казань медицинский психолог': 6},
#   {'вакансия казань образование управление': 6},
#   {'вакансия казань лидер транс': 6},
#   {'вакансия казань медбрат': 6},
#   {'вакансия втб казань': 6},
#   {'вакансия казань проектировщик': 6},
#   {'вакансия занятость казань официальный центр': 6},
#   {'авито вакансия казань студент': 6},
#   {'вакансия казань секретарь': 6},
#   {'вакансия казань разнорабочий': 6},
#   {'вакансия казань логистика': 6},
#   {'вакансия казань экономист': 6},
#   {'вакансия дверь казань': 6},
#   {'вакансия казань супермаркет': 6},
#   {'вакансия женщина казань от прямой работа работодатель': 6},
#   {'вакансия казань качество': 6},
#   {'вакансия казань техас': 6},
#   {'в вакансия казань работа фельдшер': 6},
#   {'больница вакансия инфекционный казань': 6},
#   {'wildberries вакансия казань': 6},
#   {'вакансия евроспар казань': 6},
#   {'вакансия казань срочно': 6},
#   {'вакансия казань провизор фармацевт': 6},
#   {'вакансия казань работа ру хх': 6},
#   {'вакансия казань полиция': 6},
#   {'вакансия казань мфц': 6},
#   {'английский вакансия казань': 6},
#   {'вакансия казань магазин техас': 6},
#   {'вакансия казань поликлиника': 6},
#   {'вакансия казань обь': 5},
#   {'вакансия казань кафе': 5},
#   {'вакансия газпром казань трансгаз': 5},
#   {'вакансия казань омон': 5},
#   {'в вакансия казань работа ржд': 5},
#   {'вакансия интернет казань магазин': 5},
#   {'в вакансия казань преподаватель': 5},
#   {'вакансия врач казань терапевт': 5},
#   {'вакансия казань разработчик': 5},
#   {'вакансия врач гинеколог казань': 5},
#   {'в вакансия казань энергетик': 5},
#   {'2 вакансия казань патп': 5},
#   {'вакансия жилье казань с': 5},
#   {'вакансия казань мерчендайзер': 5},
#   {'вакансия казань парикмахер': 5},
#   {'вакансия казань работа уборщица': 5},
#   {'вакансия казань контролер': 5},
#   {'вакансия казань официальный работа сайт': 5},
#   {'вакансия казань пороховой': 5},
#   {'в вакансия казань проживание с свежий': 5},
#   {'вакансия казань официальный работа': 5},
#   {'в вакансия жилье казань предоставление с': 5},
#   {'бухгалтер в вакансия казань от прямой работодатель': 5},
#   {'вакансия казань работа свежий уборщица': 5},
#   {'вакансия завод кадры казань отдел': 5},
#   {'вакансия казань росгвардия': 5},
#   {'вакансия казань экспедитор': 5},
#   {'вакансия зона иннополис казань особый экономический': 5},
#   {'бухгалтер вакансия казань от прямой': 5},
#   {'вакансия казань проводник': 5},
#   {'вакансия казань эколог': 5},
#   {'вакансия казань трансгаз': 5},
#   {'вакансия зарплата казань': 5},
#   {'вакансия вертолетный завод казань': 5},
#   {'в вакансия вахтовый казань метод стропальщик': 5},
#   {'в вакансия казань фирма': 5},
#   {'вакансия казань проводник ржд': 5},
#   {'вакансия казань лента': 5},
#   {'вакансия казань псо': 5},
#   {'вакансия дверь завод казань стальной': 5},
#   {'в вакансия казань колледж': 5},
#   {'вакансия госслужба казань': 5},
#   {'вакансия казань логист': 5},
#   {'вакансия дмитрий евгеньевич казань шпилевый': 5},
#   {'вакансия казань свежий уборщица': 5},
#   {'аптека вакансия казань': 5},
#   {'вакансия завод казань пороховой': 5},
#   {'вакансия казань работник социальный': 5},
#   {'вакансия казань работа сайт': 5},
#   {'автомобиль вакансия казань личный на': 5},
#   {'вакансия казань колледж преподаватель': 5},
#   {'вакансия казань представитель торговый': 5},
#   {'в вакансия казань медсестра работа свежий': 4},
#   {'авиационный вакансия завод казань': 4},
#   {'вакансия казань нн работа ру': 4},
#   {'вакансия казань техстрой': 4},
#   {'вакансия казань психолог работа': 4},
#   {'вакансия казань проживание с сиделка': 4},
#   {'безопасность вакансия казань транспортный': 4},
#   {'аромат вакансия казань': 4},
#   {'вакансия казань ру һһ': 4},
#   {'вакансия казань отель': 4},
#   {'вакансия казань медсестра свежий': 4},
#   {'вакансия казань от прямой работодатель хх': 4},
#   {'вакансия казань работа ру свежий хх': 4},
#   {'вакансия геолог казань': 4},
#   {'вакансия казань машинист экскаватор': 4},
#   {'вакансия для казань мужчина работа ру': 4},
#   {'вакансия казань образование официальный сайт управление': 4},
#   {'вакансия казань лаборант': 4},
#   {'вакансия казань электрик': 4},
#   {'вакансия ветеринар казань': 4},
#   {'вакансия казань хенд': 4},
#   {'авиастроительный вакансия казань': 4},
#   {'вакансия казань цех': 4}],
#  'трудоустройство казань': [{'казань трудоустройство': 37},
#   {'казань официальный трудоустройство': 8},
#   {'казань курсы трудоустройство': 2},
#   {'казань обучение с трудоустройство': 2},
#   {'для казань медосмотр трудоустройство': 2},
#   {'в казань работа трудоустройство': 1},
#   {'в казань официальный работа трудоустройство': 1},
#   {'казань район советский трудоустройство': 1},
#   {'вакансия казань официальный трудоустройство': 1},
#   {'в казань официальный сайт трудоустройство': 1},
#   {'вакансия казань трудоустройство': 1},
#   {'вакансия казань официальный сайт трудоустройство': 1}],
#  'работа в казани': [{'в казань работа': 2852},
#   {'2020 казань работа': 327},
#   {'казань работа свежий': 273},
#   {'казань от работа работодатель': 272},
#   {'авито казань работа': 235},
#   {'в казань от прямой работа': 223},
#   {'в казань от прямой работа работодатель': 212},
#   {'казань работа ривьера': 164},
#   {'банк казань работа': 160},
#   {'в казань от прямой работа работодатель свежий': 141},
#   {'в казань от работа работодатель свежий': 141},
#   {'аквапарк в казань работа': 111},
#   {'казань работа сегодня': 111},
#   {'казань м работа': 99},
#   {'казань проектирование работа': 96},
#   {'город казань работа': 95},
#   {'без казань работа': 93},
#   {'казань работа рынок': 86},
#   {'казань работа татарстан': 74},
#   {'в г казань работа': 69},
#   {'казань находить работа': 67},
#   {'казань работа ру': 65},
#   {'казань официально работа': 63},
#   {'в зоопарк казань работа': 60},
#   {'договор казань по работа': 59},
#   {'в для женщина казань работа': 58},
#   {'казань работа центр': 56},
#   {'в для казань мужчина работа': 56},
#   {'в казань проживание работа с': 55},
#   {'казань мфц работа': 54},
#   {'12 в казань работа': 52},
#   {'в казань находить работа': 51},
#   {'в казань работа республика татарстан': 50},
#   {'казань новый работа': 49},
#   {'7 казань работа': 48},
#   {'выполняться казань маневровый на почему работа станция': 48},
#   {'в казань магазин работа': 47},
#   {'казань официальный работа сайт': 47},
#   {'в искать казань работа': 44},
#   {'в казань отзыв работа': 42},
#   {'казань работа ручной': 42},
#   {'в казань музей работа': 39},
#   {'казань кафе работа': 37},
#   {'казань леруа работа': 37},
#   {'группа казань работа': 36},
#   {'2 2 в казань работа': 36},
#   {'в казань кремль работа': 36},
#   {'дом казань на работа': 34},
#   {'казань работа социальный': 34},
#   {'в вуз казань работа': 34},
#   {'казань победа работа': 33},
#   {'в казань компания работа': 33},
#   {'в казань категория работа': 32},
#   {'в казань область работа': 32},
#   {'в казань на работа устраиваться': 29},
#   {'бухгалтер в казань работа': 29},
#   {'в дорога казань работа с': 29},
#   {'казань работа ул': 28},
#   {'казань работа хх': 28},
#   {'в казань работа сайт': 28},
#   {'банк в казань работа': 27},
#   {'в казань метро работа': 27},
#   {'3 3 казань работа': 26},
#   {'авито казань от прямой работа работодатель': 25},
#   {'казань работа х х': 25},
#   {'в казань работа ресторан': 25},
#   {'авито казань от работа работодатель': 25},
#   {'аквапарк в казань работа ривьера': 25},
#   {'вахтовый казань работа': 24},
#   {'казань работа тц': 24},
#   {'авито казань проживание работа с': 23},
#   {'казань работа ру хх': 23},
#   {'гос казань работа': 23},
#   {'бухгалтер казань мусульманка работа': 23},
#   {'авто казань работа': 22},
#   {'казань работа ч': 22},
#   {'казань работа яндекс': 22},
#   {'казань налоговый работа': 22},
#   {'бахетля казань работа': 22},
#   {'казань работа рынок тур': 21},
#   {'казань работа рынок центральный': 21},
#   {'в казань работа тур': 21},
#   {'в казань работа храм': 21},
#   {'казань работа экспресс': 21},
#   {'1 2 казань работа': 20},
#   {'для женщина казань работа свежий': 20},
#   {'гибдд казань работа': 20},
#   {'казань машинист работа': 20},
#   {'в е казань категория работа': 20},
#   {'116 казань работа': 19},
#   {'автобус в казань работа': 19},
#   {'в казань поиск работа': 19},
#   {'казань нужный работа': 18},
#   {'казань пэк работа': 18},
#   {'казань лист на прайс работа сантехнический': 18},
#   {'казань работа сантехнический': 18},
#   {'2019 казань работа': 18},
#   {'в казань работа россия': 18},
#   {'ru казань работа': 18},
#   {'казань начальник работа': 18},
#   {'казань прайс работа сантехнический': 18},
#   {'казань погрузчик работа': 17},
#   {'казань почта работа россия': 17},
#   {'казань работа расценка': 17},
#   {'в казань пятерочка работа': 17},
#   {'добро казань работа': 16},
#   {'в казань медсестра работа': 16},
#   {'в казань колесо обозрение работа': 16},
#   {'вайлдберриз казань работа': 16},
#   {'добрый казань работа столовая': 16},
#   {'казань работа транспорт': 15},
#   {'алтын казань работа': 15},
#   {'казань обувь работа': 15},
#   {'втб казань работа': 15},
#   {'казань кырлай парк работа': 15},
#   {'в казань няня работа': 15},
#   {'казань машина на работа': 15},
#   {'18 казань работа': 15},
#   {'казань паспортный работа стол': 15},
#   {'автомобиль казань на работа': 15},
#   {'дорожный казань работа': 14},
#   {'5 5 в казань работа': 14},
#   {'16 казань работа': 14},
#   {'в казань повар работа': 14},
#   {'в казань магнит работа': 14},
#   {'казань нотариус работа': 14},
#   {'казань работа сдэк': 14},
#   {'14 казань работа': 14},
#   {'казань на работа тэцевский': 13},
#   {'бесплатно казань работа': 13},
#   {'казань обувь работа ручной': 13},
#   {'арена казань работа': 13},
#   {'wildberries казань работа': 13},
#   {'в казань работа сбербанк': 13},
#   {'казань работа резюме': 13},
#   {'горький казань парк работа': 13},
#   {'государственный казань работа': 13},
#   {'казань приволжский работа район': 12},
#   {'декатлон казань работа': 12},
#   {'4 4 в казань работа': 12},
#   {'ак барс казань работа': 12},
#   {'в диди казань работа': 12},
#   {'в врач казань работа': 12},
#   {'казань проектный работа': 12},
#   {'в казань работа уборщица': 12},
#   {'альфа банк казань работа': 12},
#   {'казань на работа устройство': 12},
#   {'в казань мечеть работа': 12},
#   {'в казань работа разнорабочий': 12},
#   {'казань ночной работа': 12},
#   {'бизнес казань работа': 12},
#   {'в казань работа строительный': 12},
#   {'автомаляр в казань работа': 12},
#   {'казань кольцо работа': 12},
#   {'казань отделочный работа': 12},
#   {'в вахтовый казань метод работа': 12},
#   {'бухгалтер в казань работа ру': 12},
#   {'казань работа сейчас': 11},
#   {'казань метрополитен работа': 11},
#   {'загс казань работа': 11},
#   {'в казань каменщик работа': 11},
#   {'авиастроительный казань работа': 11},
#   {'казань купить работа': 11},
#   {'в казань производство работа': 11},
#   {'казань нн работа': 11},
#   {'в казань работа электрик': 11},
#   {'вечер казань работа': 11},
#   {'казань мегастрой работа': 11},
#   {'ак банк барс казань работа': 11},
#   {'в казань мусульманка работа': 11},
#   {'авито автомаляр казань работа': 10},
#   {'в казань красота работа салон': 10},
#   {'в казань почта работа': 10},
#   {'в для казань мужчина проживание работа с': 10},
#   {'гаи казань работа': 10},
#   {'казань работа ру свежий': 10},
#   {'hh в казань работа': 10},
#   {'в казань работа стоимость': 10},
#   {'казань обь работа': 10},
#   {'казань образование работа': 10},
#   {'в воскресение казань работа': 10},
#   {'казань работа спортмастер': 10},
#   {'е казань кат работа': 10},
#   {'в казань работа рабочий': 10},
#   {'в завод казань на работа': 10},
#   {'женщина казань от прямой работа работодатель': 10},
#   {'в для казань работа студент': 10},
#   {'казань работа семья': 10},
#   {'в жилье казань работа с': 10},
#   {'агропарк казань работа': 10},
#   {'казань мастер работа': 10},
#   {'казань ооо работа': 10},
#   {'казань перспектива работа': 10},
#   {'в д казань категория работа': 10},
#   {'казань клуб работа': 9},
#   {'1 2020 голосование июль казань работа участок': 9},
#   {'в казань парк работа': 9},
#   {'в казань работа хороший': 9},
#   {'в казань продавец работа': 9},
#   {'казань парк работа хауса': 9},
#   {'авито казань от прямой работа работодатель свежий': 9},
#   {'2020 август в в казань музей работа': 9},
#   {'казань работа расписание': 9},
#   {'казань работа специалист': 9},
#   {'высокий казань работа': 9},
#   {'в икеа казань работа': 9},
#   {'казань работа тандем': 9},
#   {'казань квартира работа': 9},
#   {'в казань работа ржд': 9},
#   {'в казань офис работа': 9},
#   {'в казань коронавирус работа ресторан': 9},
#   {'казань московский работа район': 9},
#   {'земляной казань работа': 9},
#   {'казань межгород работа': 9},
#   {'в для иногородний казань проживание работа с': 9},
#   {'казань работа тендер': 9},
#   {'казань работа хантер': 9},
#   {'казань косметика работа': 9},
#   {'в иногородний казань работа': 9},
#   {'английский казань работа': 9},
#   {'казань работа театр': 9},
#   {'15 15 в казань работа': 8},
#   {'казань натяжной потолок работа': 8},
#   {'казань работа сантехника': 8},
#   {'казань мтс работа': 8},
#   {'в казань отзыв пятерочка работа сотрудник': 8},
#   {'казань н работа': 8},
#   {'жилье казань предоставление работа с': 8},
#   {'казань кафе работа ресторан': 8},
#   {'казань лента работа': 8},
#   {'казань медосмотр на работа': 8},
#   {'в казань предоставление работа с': 8},
#   {'казань работа фасадный': 8},
#   {'бургер казань кинг работа': 8},
#   {'казань от проживание прямой работа работодатель с': 8},
#   {'казань работа сантехник': 8},
#   {'в казань мчс работа': 8},
#   {'восстание казань работа': 8},
#   {'вьетнамский казань работа рынок': 8},
#   {'в зарплата казань работа': 8},
#   {'казань работа экскаватор': 8},
#   {'авито е казань категория работа': 8},
#   {'гостиница казань работа': 8},
#   {'казань отзыв пятерочка работа': 8},
#   {'в искать казань каменщик работа': 8},
#   {'казань объявление работа': 8},
#   {'казань от проживание прямой работа с': 8},
#   {'казань работа слесарь': 7},
#   {'в казань кондуктор работа': 7},
#   {'в казань макдональдс работа': 7},
#   {'казань работа форекс': 7},
#   {'казань карусель работа': 7},
#   {'казань магазин пятерочка работа': 7},
#   {'казань работа сварочный': 7},
#   {'казань кфу работа': 7},
#   {'казань работа частный': 7},
#   {'день казань на работа': 7},
#   {'казань окно работа': 7},
#   {'в видео казань работа': 7},
#   {'в девушка для казань работа': 7},
#   {'в дальнобойщик казань работа': 7},
#   {'казань поликлиника работа': 7},
#   {'казань косметика магнит работа': 7},
#   {'заказывать казань работа': 7},
#   {'в для женщина казань проживание работа с': 7},
#   {'в казань на отделочный прайс работа': 7},
#   {'в грузовой казань на работа': 7},
#   {'казань работа химик': 7},
#   {'казань компания работа транспортный': 7},
#   {'автомобиль грузовой казань на работа': 7},
#   {'казань монолитный работа': 6},
#   {'казань максид работа': 6},
#   {'армия в казань после работа': 6},
#   {'в казань монтажник работа': 6},
#   {'иннополис казань работа': 6}],
#  'казань работа вакансии': [{'вакансия казань погрузчик работа фронтальный': 4},
#   {'вакансия казань проживание работа с': 4},
#   {'вакансия казань нн работа': 4},
#   {'бухгалтер в вакансия казань работа свежий': 4},
#   {'бухгалтер вакансия казань работа': 4},
#   {'вакансия казань от прямой работа хх': 4},
#   {'вакансия город казань работа': 4},
#   {'в вакансия казань проводник работа ржд': 3},
#   {'вакансия казань няня работа': 3},
#   {'вакансия казань пятерочка работа': 3},
#   {'hh вакансия казань работа': 3},
#   {'авито в вакансия казань на работа свежий': 3},
#   {'аэропорт в вакансия казань работа': 3},
#   {'вакансия икеа казань на официальный работа сайт': 3},
#   {'в вакансия завод казань на работа': 3},
#   {'в вакансия казань мини на погрузчик работа': 3},
#   {'вакансия икеа казань на работа': 3},
#   {'банк вакансия казань работа': 2},
#   {'в вакансия казань находить работа свежий': 2},
#   {'вакансия казань на обь работа': 2},
#   {'вакансия казань обучение работа с': 2},
#   {'ru вакансия казань работа': 2},
#   {'вакансия газета казань работа': 2},
#   {'wildberries в вакансия казань работа': 2},
#   {'в вакансия казань на работа свежий сегодня': 2},
#   {'банк в вакансия казань работа': 2},
#   {'вакансия выходной казань на работа': 2},
#   {'авито вакансия казань работа ру': 2},
#   {'hh ru вакансия казань работа': 2},
#   {'в вакансия интернет казань работа': 2},
#   {'в вакансия казань мчс работа': 2},
#   {'вакансия казань просто работа': 2},
#   {'1000 вакансия казань работа': 2},
#   {'архив в вакансия казань работа': 2},
#   {'вакансия казань работа склад': 2},
#   {'библиотекарь в вакансия казань работа': 1},
#   {'в вакансия занятость казань работа центр': 1},
#   {'в вакансия казань работа ру свежий': 1},
#   {'в вакансия казань массажист работа': 1},
#   {'вакансия казань работа сиделка': 1},
#   {'без в вакансия казань посредник работа': 1},
#   {'в вакансия казань работа суд': 1},
#   {'в вакансия казань работа сантехник': 1},
#   {'в вайлдберриз вакансия казань работа': 1},
#   {'вакансия казань медицинский работа сестра': 1},
#   {'hh вакансия казань работа свежий': 1},
#   {'вакансия иннополис казань работа': 1},
#   {'в вакансия казань метро работа': 1},
#   {'hh ru вакансия казань работа свежий': 1},
#   {'в вакансия казань мегастрой работа': 1},
#   {'avito вакансия казань работа': 1},
#   {'вакансия казань озон работа': 1},
#   {'авито вакансия казань работа сегодня': 1},
#   {'в вакансия казань мфц работа': 1},
#   {'в вакансия казань работа свежий сиделка': 1},
#   {'в вакансия газпром казань работа': 1},
#   {'в вакансия казань работа сантехника': 1}],
#  'вакансии работодателя казань': [{'вакансия для женщина казань от прямой работодатель': 4},
#   {'бухгалтер вакансия казань от прямой работодатель свежий': 4},
#   {'вакансия казань от прямой работодатель хедхантер': 3},
#   {'вакансия казань от прямой работодатель свежий хедхантер': 3},
#   {'в вакансия казань няня от прямой работодатель': 2},
#   {'вакансия валберис казань от прямой работодатель': 2},
#   {'вакансия казань от прямой работодатель уборщица': 2},
#   {'вакансия казань нн от прямой работодатель': 2},
#   {'в вакансия казань медсестра от прямой работодатель': 2},
#   {'в вакансия казань мерчендайзер от прямой работодатель': 1},
#   {'вакансия казань от проживание прямой работодатель с': 1},
#   {'в вакансия казань от прямой психолог работодатель': 1},
#   {'в вакансия казань от производство прямой работодатель': 1},
#   {'администратор вакансия казань прямой работодатель': 1},
#   {'в вакансия казань от прямой работодатель руководитель': 1},
#   {'вакансия казань от прямой работодатель сегодня': 1}],
#  'авито работа казань': [{'авито для казань работа студент': 6},
#   {'авито казань работа ру': 5},
#   {'авито казань на работа фасовщица': 4},
#   {'авито в дальнобойщик казань на работа': 3},
#   {'авито в казань работа свежий': 3},
#   {'2 2 авито казань работа': 2},
#   {'авито казань повар работа': 2},
#   {'авито в казань на находить работа': 2},
#   {'авито казань работа упаковщица': 2},
#   {'авито казань на работа уборщица': 2},
#   {'авито июль казань работа': 1},
#   {'авито в казань на от прямой работа': 1},
#   {'авито казань работа сегодня': 1},
#   {'авито высокий гора казань работа': 1},
#   {'авито казань официант работа': 1},
#   {'авито бухгалтер казань работа': 1},
#   {'авито в искать казань на работа': 1}],
#  'авито казань вакансии': [{'авито вакансия казань сиделка': 2},
#   {'авито вакансия казань ру': 2},
#   {'авито в вакансия казань от прямой': 2},
#   {'авито вакансия казань сегодня': 1},
#   {'авито вакансия казань швея': 1},
#   {'авито вакансия для казань мужчина': 1}],
#  'свежие вакансии казань': [{'вакансия казань ру свежий хх': 4},
#   {'бухгалтер вакансия казань свежий': 4},
#   {'вакансия казань свежий хх': 4},
#   {'вакансия казань разнорабочий свежий': 2},
#   {'вакансия казань находить свежий': 2},
#   {'вакансия город казань свежий': 2},
#   {'вакансия вакансия казань свежий сегодня': 2},
#   {'вакансия вакансия казань свежий сиделка': 2},
#   {'администратор вакансия вакансия казань свежий': 2},
#   {'в вакансия казань проживание с свежий сиделка': 2},
#   {'вакансия вакансия занятость казань свежий центр': 1},
#   {'hh ru вакансия казань свежий': 1},
#   {'hh вакансия казань свежий': 1},
#   {'вакансия вахтер казань свежий': 1},
#   {'вакансия казань руководитель свежий': 1}],
#  'работа казань свежие': [{'в казань работа свежий уборщица': 5},
#   {'казань работа ру свежий хх': 4},
#   {'бухгалтер казань работа свежий': 4},
#   {'в казань медсестра работа свежий': 4},
#   {'без казань работа свежий': 3},
#   {'в казань находить работа свежий': 2},
#   {'казань работа свежий сегодня': 2},
#   {'hh казань работа свежий': 1},
#   {'hh ru казань работа свежий': 1},
#   {'без казань посредник работа свежий сиделка': 1},
#   {'казань работа ру свежий ххра': 1}],
#  'центр занятости казань': [{'занятость казань центр': 102},
#   {'занятость казань население центр': 22},
#   {'занятость казань кировский центр': 14},
#   {'занятость казань район советский центр': 14},
#   {'занятость казань советский центр': 14},
#   {'занятость казань кировский район центр': 14},
#   {'занятость казань официальный центр': 12},
#   {'занятость казань сайт центр': 11},
#   {'занятость казань официальный сайт центр': 10},
#   {'г занятость казань центр': 9},
#   {'занятость кабинет казань личный центр': 8},
#   {'занятость казань новый савиновский центр': 8},
#   {'г занятость казань район советский центр': 6},
#   {'занятость казань приволжский центр': 6},
#   {'занятость казань население район советский центр': 5},
#   {'занятость казань телефон центр': 5},
#   {'занятость казань население советский центр': 5},
#   {'занятость казань новый район савиновский центр': 5},
#   {'занятость казань кировский население район центр': 4},
#   {'занятость казань кировский население центр': 4},
#   {'занятость казань московский район центр': 4},
#   {'г занятость казань население центр': 4},
#   {'занятость казань кировский район телефон центр': 4},
#   {'занятость казань приволжский район центр': 4},
#   {'занятость казань московский центр': 4},
#   {'г занятость казань население район советский центр': 3},
#   {'вакансия занятость казань новый савиновский центр': 3},
#   {'занятость казань население телефон центр': 3},
#   {'гагарин занятость казань центр': 3},
#   {'занятость казань официальный район советский центр': 2},
#   {'46 гагарин занятость казань центр': 2},
#   {'занятость кабинет казань личный население центр': 2},
#   {'авиастроительный занятость казань центр': 2},
#   {'город занятость казань центр': 2},
#   {'занятость казань курсы центр': 2},
#   {'авиастроительный занятость казань район центр': 2},
#   {'занятость казань московский район телефон центр': 1},
#   {'занятость казань курсы район советский центр': 1},
#   {'г занятость казань приволжский район центр': 1},
#   {'занятость интерактивный казань население портал центр': 1},
#   {'гку занятость казань население центр': 1},
#   {'занятость казань кировский район сайт центр': 1},
#   {'занятость казань район советский труд центр': 1},
#   {'занятость казань труд центр': 1},
#   {'вакансия занятость казань население центр': 1},
#   {'декретница для занятость казань курсы центр': 1},
#   {'город занятость казань приволжский район центр': 1},
#   {'вакансия занятость казань московский район центр': 1},
#   {'город занятость казань население центр': 1},
#   {'занятость интерактивный казань портал центр': 1},
#   {'в занятость казань работа центр': 1},
#   {'г гку занятость казань население центр': 1},
#   {'г занятость казань кировский район центр': 1},
#   {'2020 занятость казань курсы центр': 1}],
#  'работа сегодня казань': [{'в икеа казань работа сегодня': 4},
#   {'в казань работа сбербанк сегодня': 3},
#   {'в для женщина казань работа сегодня': 2},
#   {'казань оплата работа с сегодня': 2}],
#  'работа казань банки': [{'банк казань почта работа': 5},
#   {'банк казань отзыв работа': 5},
#   {'банк казань отделение работа': 3},
#   {'банк казань отп работа': 1},
#   {'банк казань работа тимер': 1}],
#  'казань работа без': [{'без казань оформление работа': 5},
#   {'без казань посредник работа': 5},
#   {'без в казань образование работа': 2},
#   {'автомобиль без в казань личный работа': 2},
#   {'без в казань посредник работа сиделка': 1},
#   {'без в казань проживание работа сиделка': 1},
#   {'без день каждый казань оплата оформление работа': 1}],
#  'биржа труда казань': [{'биржа казань труд': 45},
#   {'биржа казань новый савиновский труд': 8},
#   {'биржа казань новый район савиновский труд': 8},
#   {'биржа казань телефон труд': 6},
#   {'биржа казань московский труд': 5},
#   {'биржа казань кировский район телефон труд': 3},
#   {'биржа казань московский район труд': 3},
#   {'биржа казань кировский труд': 3},
#   {'биржа казань официальный труд': 3},
#   {'биржа казань кировский район труд': 3},
#   {'биржа вставать госуслуга казань на труд через': 3},
#   {'биржа казань официальный сайт труд': 3},
#   {'биржа казань сайт труд': 3},
#   {'биржа казань район советский труд': 2},
#   {'биржа казань новый район савиновский телефон труд': 2},
#   {'биржа вакансия казань труд': 2},
#   {'биржа в вставать казань как на труд': 2},
#   {'биржа казань приволжский район труд': 2},
#   {'биржа казань советский труд': 2},
#   {'биржа казань приволжский труд': 2},
#   {'биржа казань приволжский район телефон труд': 1},
#   {'биржа документ казань какой труд': 1},
#   {'биржа казань как на становиться труд': 1}],
#  'курсы трудоустройством казань': [],
#  'вакансии казань от прямых': [{'вакансия казань от прямой хх': 4},
#   {'вакансия казань от прямой хедхантер': 3},
#   {'вакансия казань медсестра от прямой': 2},
#   {'вакансия казань мерчендайзер от прямой': 2},
#   {'вакансия казань от проживание прямой с': 1}],
#  'работа от работодателей казань': [{'казань от прямой работа работодатель ру': 6},
#   {'в казань находить от работа работодатель': 5},
#   {'бухгалтер в казань от прямой работа работодатель': 5},
#   {'казань от прямой работа работодатель хх': 4},
#   {'казань от прямой работа работодатель склад': 3},
#   {'в казань от прямой работа работодатель слесарь': 3},
#   {'казань медсестра от прямой работа работодатель': 2},
#   {'в казань няня от прямой работа работодатель': 2},
#   {'казань находить прямой работа работодатель': 2},
#   {'в казань няня от работа работодатель': 2},
#   {'в казань от прямой работа работодатель юрист': 1},
#   {'в казань напрямую находить от работа работодатель': 1},
#   {'hh казань от прямой работа работодатель': 1},
#   {'в казань поиск работа работодатель': 1},
#   {'в казань от поиск прямой работа работодатель': 1},
#   {'казань напрямую от работа работодатель': 1}],
#  'работа казань прямой работодатель': [],
#  'работа в казани от прямых': [{'бухгалтер в казань от прямой работа': 5},
#   {'в казань от поиск прямой работа': 3},
#   {'в казань находить от прямой работа': 2},
#   {'в казань няня от прямой работа': 2},
#   {'в казань медсестра от прямой работа': 2},
#   {'hh ru казань от прямой работа': 1},
#   {'в казань от прямой работа юрист': 1},
#   {'hh казань от прямой работа': 1}]}

# %%
def kw_to_cluster(dictionary, keyword):
    '''
    Преобразование вложенных в отчет по ключевому слову словарей в список ключевых запросов
    '''
    phrases_list = []
    if len(dictionary) == 0:
        phrases_list.append(keyword)
        return phrases_list
    else:
        for dict_ in dictionary[keyword]:
            for key_kw in dict_.keys():
                phrases_list.append(key_kw)
    return phrases_list

def group_name(cluster_name, word_list):
    '''
    Возвращает название группы в виде строки
    '''
    m = Mystem()
    lemmas = m.lemmatize(cluster_name)
    for i in [' ', '.', ',', '\n']:
        while i in lemmas:
            lemmas.remove(i)
    if 'ипать' in lemmas:
        lemmas[lemmas.index('ипать')] = 'ип'
    if 'банка' in lemmas:
        lemmas[lemmas.index('банка')] = 'банк'
    if 'усна' in lemmas:
        lemmas[lemmas.index('усна')] = 'усн'
    if 'юла' in lemmas:
        lemmas[lemmas.index('юла')] = 'юл'
    # Лемма названия ключевого слова
    word_list.sort(key=lambda x: len(x.split()))
    short_word_list = word_list[0].split()

    for word in short_word_list:
        if word not in lemmas:
            gr_name_list = cluster_name.split()
            gr_name_list.append(word)
            return re.sub(r'[+]','',' '.join(gr_name_list))
    return re.sub(r'[+]','',cluster_name)


def yandex_keyword_dict(dictionary_keywords):
    '''
    Возвращает словарь групп ключевых слов с названиями
    :param dictionary_keywords: dict
    :return: dict
    '''

    new_dict = {}
    for key in dictionary_keywords.keys():
        list_exact = ['"{}"'.format(x) for x in dictionary_keywords[key]]
        new_dict[key] = [dictionary_keywords[key], list_exact]
        key_exact = '"{}"'.format(key)
        new_dict.update({key_exact: list_exact})

    return new_dict


def clusters(dictionary, freq=2):
    '''
    Кластеризация запросов с регулируемой частотой вхождения
    '''
    ready_dict = {}
    keyw_dict = {}
    for key in dictionary.keys():
        ready_dict.setdefault(key, [])
        phrases = kw_to_cluster(dictionary, key)
        if len(phrases) == 1:
            dct = {0: phrases}
        elif len(phrases) == 0:
            continue
        else:
            cv2 = CountVectorizer(min_df=freq)

            X = cv2.fit_transform(phrases)
            link_M = linkage(X.toarray(), method='ward')
            clusters = fcluster(link_M,
                                int(np.round(np.divide(len(phrases), 5))),
                                criterion='maxclust')
            dct = {}
            for key_, label in zip(phrases, clusters):
                dct[label] = dct.get(label, []) + [key_]

        for x in dct.keys():
            count = 0
            for keyword in dct[x]:
                for dict_kw in dictionary[key]:
                    if keyword in dict_kw.keys():
                        count += dict_kw[keyword]
            grName = group_name(key, dct[x])
            ready_dict[key].append([dct[x], count, grName])
            keyw_dict.setdefault(grName, dct[x])
    new_dict_kw = yandex_keyword_dict(keyw_dict)
    return ready_dict, new_dict_kw

# %%
phrases, kw_s = clusters(kw_Dict1)

# %%
phrases
# Out:
# {'вакансии казань': [[['вакансия казань',
#     'бухгалтер вакансия казань',
#     'вакансия казань ооо',
#     'вакансия г казань',
#     'вакансия казань менеджер',
#     'банк вакансия казань',
#     'вакансия дорога казань',
#     'вакансия казань помощник',
#     'вакансия директор казань',
#     'вакансия казань руководитель',
#     'вакансия казань технолог',
#     'вакансия город казань',
#     'администратор вакансия казань',
#     'вакансия казань телематика',
#     'вакансия валберис казань',
#     'вакансия казань продавец',
#     'вакансия казань техник',
#     'аэропорт вакансия казань',
#     'вакансия казань мастер',
#     'вакансия казань татнефть',
#     'вакансия казань чоп',
#     'вакансия казань монтажник',
#     'вакансия казань юрист',
#     'вакансия казань мадоу',
#     'вакансия казань цветок',
#     'вакансия казань производство',
#     'вакансия казань пятерочка',
#     'вакансия казань программист',
#     'вакансия казань туризм',
#     'вакансия казань продажа',
#     'вакансия казань озон',
#     'вакансия казань ркб',
#     'вакансия домработница казань',
#     'вакансия казань стоматолог',
#     'вакансия казань слесарь',
#     'бесплатный вакансия казань',
#     'вакансия казань м',
#     'вакансия казань леруа',
#     'вакансия казань клиника',
#     'вакансия казань рычаг',
#     'вакансия казань культура',
#     'вакансия казань метро',
#     'вакансия казань хантер',
#     'вакансия ветеринарный казань',
#     'вакансия казань элекон',
#     'вакансия казань ресторан',
#     'вакансия казань логопед',
#     'автобус вакансия казань',
#     'вакансия казань яндекс',
#     'вакансия казань перекресток',
#     'вакансия дизайнер казань',
#     'вакансия казань экспресс',
#     'вакансия казань труд',
#     'вакансия казань мчс',
#     'вакансия казань магнит',
#     'вакансия казань энергетика',
#     'вакансия жби казань',
#     'вакансия диспетчер казань',
#     'автосфера вакансия казань',
#     'вакансия икеа казань',
#     'вакансия казань размещать',
#     'вакансия казань фссп',
#     'вакансия казань медбрат',
#     'вакансия втб казань',
#     'вакансия казань проектировщик',
#     'вакансия казань секретарь',
#     'вакансия казань разнорабочий',
#     'вакансия казань логистика',
#     'вакансия казань экономист',
#     'вакансия казань супермаркет',
#     'вакансия казань качество',
#     'wildberries вакансия казань',
#     'вакансия евроспар казань',
#     'вакансия казань срочно',
#     'вакансия казань полиция',
#     'вакансия казань мфц',
#     'английский вакансия казань',
#     'вакансия казань поликлиника',
#     'вакансия казань обь',
#     'вакансия казань кафе',
#     'вакансия казань омон',
#     'вакансия казань разработчик',
#     'вакансия казань мерчендайзер',
#     'вакансия казань парикмахер',
#     'вакансия казань контролер',
#     'вакансия казань росгвардия',
#     'вакансия казань экспедитор',
#     'вакансия казань эколог',
#     'вакансия зарплата казань',
#     'вакансия казань лента',
#     'вакансия казань псо',
#     'вакансия госслужба казань',
#     'вакансия казань логист',
#     'аптека вакансия казань',
#     'вакансия казань техстрой',
#     'аромат вакансия казань',
#     'вакансия казань отель',
#     'вакансия геолог казань',
#     'вакансия казань лаборант',
#     'вакансия казань электрик',
#     'вакансия ветеринар казань',
#     'вакансия казань хенд',
#     'авиастроительный вакансия казань',
#     'вакансия казань цех',
#     'вакансия е казань категория',
#     '2 2 вакансия казань',
#     'в вакансия казань сфера',
#     '3 3 вакансия казань',
#     'в вакансия казань сегодня',
#     'в вакансия делопроизводитель казань',
#     'в вакансия казань стропальщик',
#     'вакансия казань лидер транс',
#     'больница вакансия инфекционный казань',
#     'в вакансия казань энергетик',
#     'в вакансия казань фирма',
#     'вакансия казань представитель торговый',
#     'вакансия дмитрий евгеньевич казань шпилевый'],
#    4492,
#    'вакансии казань'],
#   [['вакансия казань работа',
#     'авито вакансия казань работа',
#     'вакансия женщина казань работа',
#     'вакансия казань работа студент',
#     'вакансия казань психолог работа'],
#    650,
#    'вакансии казань работа'],
#   [['вакансия казань свежий',
#     'вакансия женщина казань свежий',
#     'вакансия е казань свежий',
#     'в вакансия казань работа свежий',
#     'в вакансия казань ковров работа свежий'],
#    585,
#    'вакансии казань свежий'],
#   [['вакансия казань работодатель',
#     'авито вакансия казань',
#     'вакансия казань работодатель свежий',
#     'авито вакансия казань работодатель',
#     'авито вакансия казань работа работодатель'],
#    661,
#    'вакансии казань работодатель'],
#   [['вакансия казань от прямой',
#     'вакансия казань от прямой работа',
#     'вакансия казань от прямой работа свежий'],
#    621,
#    'вакансии казань от'],
#   [['вакансия казань казань от прямой работодатель',
#     'вакансия казань механик от прямой работодатель',
#     'вакансия казань от прямой работодатель хх'],
#    296,
#    'вакансии казань от'],
#   [['вакансия казань от прямой работа работодатель',
#     'вакансия казань от прямой работа работодатель свежий',
#     'вакансия казань мужчина от прямой работа работодатель',
#     'вакансия женщина казань от прямой работа работодатель'],
#    355,
#    'вакансии казань от'],
#   [['вакансия казань от прямой свежий',
#     'авито вакансия казань от прямой свежий',
#     'авито вакансия казань от работодатель свежий',
#     'в вакансия казань от прямой работодатель свежий',
#     'авито вакансия казань от прямой работодатель свежий'],
#    361,
#    'вакансии казань от'],
#   [['вакансия казань сайт',
#     'вакансия казань оргсинтез',
#     'вакансия казань официальный сайт',
#     'вакансия казань оргсинтез сайт',
#     'вакансия казань оргсинтез официальный сайт'],
#    212,
#    'вакансии казань сайт'],
#   [['вакансия завод казань',
#     'вакансия дверь казань',
#     'вакансия казань пороховой',
#     'вакансия вертолетный завод казань',
#     'вакансия завод казань пороховой',
#     'авиационный вакансия завод казань',
#     'вакансия дверь завод казань стальной'],
#    94,
#    'вакансии казань завод'],
#   [['hh вакансия казань', 'hh ru вакансия казань'], 65, 'вакансии казань hh'],
#   [['вакансия казань склад',
#     'вайлдберриз вакансия казань',
#     'в вайлдберриз вакансия казань склад'],
#    75,
#    'вакансии казань склад'],
#   [['вакансия казань ру',
#     'вакансия казань нн',
#     'вакансия казань нн ру',
#     'вакансия казань ру һһ',
#     'вакансия казань нн работа ру'],
#    75,
#    'вакансии казань ру'],
#   [['без вакансия казань', 'без вакансия казань посредник'],
#    41,
#    'вакансии казань без'],
#   [['вакансия казань мужчина',
#     'вакансия казань мужчина работа',
#     'вакансия для казань мужчина работа ру'],
#    57,
#    'вакансии казань мужчина'],
#   [['вакансия казань хедхантер', 'вакансия казань свежий хедхантер'],
#    37,
#    'вакансии казань хедхантер'],
#   [['вакансия казань ржд',
#     'вакансия казань проводник',
#     'вакансия казань проводник ржд',
#     'в вакансия казань работа ржд'],
#    42,
#    'вакансии казань ржд'],
#   [['в вакансия для женщина казань',
#     'в вакансия для женщина казань работа свежий'],
#    46,
#    'вакансии казань в'],
#   [['авито вакансия казань от прямой работодатель',
#     'авито вакансия казань от прямой работа',
#     'авито вакансия казань от прямой работа работодатель'],
#    65,
#    'вакансии казань авито'],
#   [['вакансия казань центр',
#     'вакансия занятость казань центр',
#     'вакансия занятость казань сайт центр',
#     'вакансия занятость казань официальный центр',
#     'вакансия занятость казань официальный сайт центр'],
#    59,
#    'вакансии казань центр'],
#   [['вакансия казань магазин',
#     'вакансия казань техас',
#     'вакансия казань магазин техас',
#     'вакансия интернет казань магазин'],
#    43,
#    'вакансии казань магазин'],
#   [['вакансия газпром казань',
#     'вакансия казань трансгаз',
#     'вакансия газпром казань трансгаз'],
#    34,
#    'вакансии казань газпром'],
#   [['вакансия казань сиделка',
#     'в вакансия казань пансионат сиделка',
#     'вакансия казань проживание с сиделка'],
#    34,
#    'вакансии казань сиделка'],
#   [['вакансия казань начальник', 'вакансия казань начальник отдел'],
#    29,
#    'вакансии казань начальник'],
#   [['вакансия казань машинист',
#     'вакансия казань машинист электропоезд',
#     'вакансия казань машинист экскаватор'],
#    31,
#    'вакансии казань машинист'],
#   [['вакансия казань педиатр',
#     'вакансия казань терапевт',
#     'в вакансия врач казань',
#     'вакансия врач казань педиатр',
#     'вакансия врач казань терапевт'],
#    48,
#    'вакансии казань педиатр'],
#   [['вакансия казань транспортный',
#     'безопасность вакансия казань',
#     'вакансия казань компания транспортный',
#     'безопасность вакансия казань транспортный'],
#    40,
#    'вакансии казань транспортный'],
#   [['вакансия иннополис казань',
#     'вакансия зона иннополис казань особый экономический'],
#    25,
#    'вакансии казань иннополис'],
#   [['вакансия казань хх',
#     'вакансия казань работа ру',
#     'вакансия казань ру хх',
#     'вакансия казань работа хх',
#     'вакансия казань работа ру хх',
#     'вакансия казань работа ру свежий хх'],
#    53,
#    'вакансии казань хх'],
#   [['вакансия казань проживание с', 'в вакансия казань проживание с свежий'],
#    23,
#    'вакансии казань проживание'],
#   [['вакансия казань психолог',
#     'вакансия казань медицинский',
#     'вакансия казань медицинский психолог'],
#    40,
#    'вакансии казань психолог'],
#   [['в вакансия для казань мужчина свежий',
#     'в вакансия для казань мужчина работа свежий'],
#    32,
#    'вакансии казань в'],
#   [['вакансия казань фармацевт',
#     'вакансия казань провизор',
#     'вакансия казань провизор фармацевт'],
#    30,
#    'вакансии казань фармацевт'],
#   [['авито вакансия казань на свежий'], 16, 'вакансии казань авито'],
#   [['вакансия казань уборщица',
#     'вакансия казань работа уборщица',
#     'вакансия казань свежий уборщица',
#     'вакансия казань работа свежий уборщица'],
#    30,
#    'вакансии казань уборщица'],
#   [['в вакансия казань медсестра',
#     'вакансия казань медсестра свежий',
#     'в вакансия казань медсестра работа',
#     'в вакансия казань медсестра работа свежий'],
#    29,
#    'вакансии казань в'],
#   [['вакансия кадры казань отдел',
#     'вакансия дом кадры казань',
#     'вакансия завод кадры казань отдел'],
#    26,
#    'вакансии казань кадры'],
#   [['вакансия казань механик', 'вакансия казань механик по транспорт'],
#    28,
#    'вакансии казань механик'],
#   [['hh вакансия казань от прямой',
#     'hh вакансия казань от работодатель',
#     'hh вакансия казань от прямой работодатель',
#     'hh ru вакансия казань от прямой',
#     'hh ru вакансия казань от прямой работодатель'],
#    55,
#    'вакансии казань hh'],
#   [['вакансия казань строительный',
#     'в вакансия казань компания',
#     'вакансия казань компания строительный'],
#    36,
#    'вакансии казань строительный'],
#   [['вакансия казань медработник',
#     'вакансия казань медосмотр медработник по предрейсовый'],
#    25,
#    'вакансии казань медработник'],
#   [['вакансия казань фикс', 'вакансия казань прайс фикс'],
#    21,
#    'вакансии казань фикс'],
#   [['вакансия для казань студент', 'авито вакансия казань студент'],
#    17,
#    'вакансии казань для'],
#   [['вакансия дом казань на',
#     'вакансия казань на работа сегодня',
#     'вакансия дом казань на работа',
#     'автомобиль вакансия казань личный на'],
#    29,
#    'вакансии казань дом'],
#   [['вакансия казань управление',
#     'вакансия казань образование',
#     'вакансия казань образование управление',
#     'вакансия казань образование официальный сайт управление'],
#    28,
#    'вакансии казань управление'],
#   [['вакансия казань менеджер по продажа'], 9, 'вакансии казань менеджер'],
#   [['вакансия казань организатор', 'вакансия казань организатор педагог'],
#    17,
#    'вакансии казань организатор'],
#   [['вакансия гинеколог казань', 'вакансия врач гинеколог казань'],
#    14,
#    'вакансии казань гинеколог'],
#   [['вакансия казань фельдшер', 'в вакансия казань работа фельдшер'],
#    15,
#    'вакансии казань фельдшер'],
#   [['вакансия казань находить', 'вакансия казань находить работа'],
#    14,
#    'вакансии казань находить'],
#   [['вакансия казань новый савиновский',
#     'вакансия казань новый район савиновский'],
#    16,
#    'вакансии казань новый'],
#   [['вакансия казань поиск', 'в вакансия казань поиск работа'],
#    16,
#    'вакансии казань поиск'],
#   [['вакансия казань погрузчик', 'вакансия казань погрузчик работа'],
#    15,
#    'вакансии казань погрузчик'],
#   [['вакансия казань работник', 'вакансия казань работник социальный'],
#    12,
#    'вакансии казань работник'],
#   [['вакансия казань патп', '2 вакансия казань патп'],
#    12,
#    'вакансии казань патп'],
#   [['вакансия вахтовый казань метод',
#     'в вакансия вахтовый казань метод стропальщик'],
#    12,
#    'вакансии казань вахтовый'],
#   [['в вакансия казань преподаватель',
#     'в вакансия казань колледж',
#     'вакансия казань колледж преподаватель'],
#    15,
#    'вакансии казань в'],
#   [['вакансия жилье казань с', 'в вакансия жилье казань предоставление с'],
#    10,
#    'вакансии казань жилье'],
#   [['вакансия казань официальный работа',
#     'вакансия казань работа сайт',
#     'вакансия казань официальный работа сайт'],
#    15,
#    'вакансии казань официальный'],
#   [['бухгалтер вакансия казань от прямой',
#     'бухгалтер в вакансия казань от прямой работодатель'],
#    10,
#    'вакансии казань бухгалтер']],
#  'трудоустройство казань': [[['казань трудоустройство',
#     'казань курсы трудоустройство',
#     'казань обучение с трудоустройство',
#     'для казань медосмотр трудоустройство',
#     'в казань работа трудоустройство',
#     'казань район советский трудоустройство'],
#    45,
#    'трудоустройство казань'],
#   [['казань официальный трудоустройство',
#     'вакансия казань трудоустройство',
#     'вакансия казань официальный трудоустройство',
#     'в казань официальный работа трудоустройство',
#     'в казань официальный сайт трудоустройство',
#     'вакансия казань официальный сайт трудоустройство'],
#    13,
#    'трудоустройство казань официальный']],
#  'работа в казани': [[['в казань работа',
#     'казань работа сегодня',
#     'казань м работа',
#     'казань проектирование работа',
#     'город казань работа',
#     'без казань работа',
#     'казань официально работа',
#     'казань работа центр',
#     'казань мфц работа',
#     'казань новый работа',
#     '7 казань работа',
#     'казань леруа работа',
#     'группа казань работа',
#     'казань работа социальный',
#     'казань победа работа',
#     'казань работа ул',
#     'казань работа тц',
#     'гос казань работа',
#     'авто казань работа',
#     'казань работа ч',
#     'казань работа яндекс',
#     'казань налоговый работа',
#     'бахетля казань работа',
#     'казань работа экспресс',
#     'гибдд казань работа',
#     'казань машинист работа',
#     '116 казань работа',
#     'казань нужный работа',
#     'казань пэк работа',
#     '2019 казань работа',
#     'ru казань работа',
#     'казань начальник работа',
#     'казань погрузчик работа',
#     'казань работа расценка',
#     'добро казань работа',
#     'вайлдберриз казань работа',
#     'казань работа транспорт',
#     'алтын казань работа',
#     'втб казань работа',
#     '18 казань работа',
#     'дорожный казань работа',
#     '16 казань работа',
#     'казань нотариус работа',
#     'казань работа сдэк',
#     '14 казань работа',
#     'бесплатно казань работа',
#     'арена казань работа',
#     'wildberries казань работа',
#     'казань работа резюме',
#     'государственный казань работа',
#     'декатлон казань работа',
#     'казань проектный работа',
#     'казань ночной работа',
#     'бизнес казань работа',
#     'казань кольцо работа',
#     'казань работа сейчас',
#     'казань метрополитен работа',
#     'загс казань работа',
#     'авиастроительный казань работа',
#     'казань купить работа',
#     'казань нн работа',
#     'вечер казань работа',
#     'казань мегастрой работа',
#     'гаи казань работа',
#     'казань обь работа',
#     'казань образование работа',
#     'казань работа спортмастер',
#     'казань работа семья',
#     'агропарк казань работа',
#     'казань мастер работа',
#     'казань ооо работа',
#     'казань перспектива работа',
#     'казань клуб работа',
#     'казань работа расписание',
#     'казань работа специалист',
#     'высокий казань работа',
#     'казань работа тандем',
#     'казань квартира работа',
#     'земляной казань работа',
#     'казань межгород работа',
#     'казань работа тендер',
#     'казань работа хантер',
#     'английский казань работа',
#     'казань работа театр',
#     'казань работа сантехника',
#     'казань мтс работа',
#     'казань н работа',
#     'казань лента работа',
#     'казань работа фасадный',
#     'казань работа сантехник',
#     'восстание казань работа',
#     'казань работа экскаватор',
#     'гостиница казань работа',
#     'казань объявление работа',
#     'казань работа слесарь',
#     'казань работа форекс',
#     'казань карусель работа',
#     'казань работа сварочный',
#     'казань кфу работа',
#     'казань работа частный',
#     'казань окно работа',
#     'казань поликлиника работа',
#     'заказывать казань работа',
#     'казань работа химик',
#     'казань монолитный работа',
#     'казань максид работа',
#     'иннополис казань работа',
#     'в г казань работа',
#     'в зоопарк казань работа',
#     'договор казань по работа',
#     '12 в казань работа',
#     'в казань кремль работа',
#     'в вуз казань работа',
#     'в казань область работа',
#     'в казань метро работа',
#     '3 3 казань работа',
#     'казань работа х х',
#     'в казань работа храм',
#     '1 2 казань работа',
#     'автобус в казань работа',
#     'в казань поиск работа',
#     'в казань медсестра работа',
#     'добрый казань работа столовая',
#     'в казань няня работа',
#     'казань паспортный работа стол',
#     'в казань повар работа',
#     'в казань работа сбербанк',
#     'в диди казань работа',
#     'в врач казань работа',
#     'в казань работа уборщица',
#     'в казань мечеть работа',
#     'в казань работа разнорабочий',
#     'в казань работа строительный',
#     'в казань производство работа',
#     'в казань работа электрик',
#     'hh в казань работа',
#     'в казань работа стоимость',
#     'в воскресение казань работа',
#     'е казань кат работа',
#     'в казань работа рабочий',
#     'в казань работа хороший',
#     'в казань продавец работа',
#     'в икеа казань работа',
#     'в казань работа ржд',
#     'в казань офис работа',
#     'казань натяжной потолок работа',
#     'бургер казань кинг работа',
#     'в казань мчс работа',
#     'в зарплата казань работа',
#     'в казань кондуктор работа',
#     'в казань макдональдс работа',
#     'в видео казань работа',
#     'в дальнобойщик казань работа',
#     'в казань монтажник работа',
#     '2 2 в казань работа',
#     'в дорога казань работа с',
#     'в казань колесо обозрение работа',
#     '5 5 в казань работа',
#     '4 4 в казань работа',
#     'в казань красота работа салон',
#     '15 15 в казань работа',
#     'армия в казань после работа'],
#    5860,
#    'работа в казани'],
#   [['2020 казань работа', '1 2020 голосование июль казань работа участок'],
#    336,
#    'работа в казани 2020'],
#   [['казань работа свежий', 'казань работа ру свежий'],
#    283,
#    'работа в казани свежий'],
#   [['казань от работа работодатель',
#     'в казань от прямой работа работодатель',
#     'женщина казань от прямой работа работодатель'],
#    494,
#    'работа в казани от'],
#   [['авито казань работа',
#     'в казань проживание работа с',
#     'авито казань проживание работа с'],
#    313,
#    'работа в казани авито'],
#   [['в казань от прямой работа',
#     'казань от проживание прямой работа с',
#     'казань от проживание прямой работа работодатель с'],
#    239,
#    'работа в казани от'],
#   [['казань работа ривьера',
#     'аквапарк в казань работа',
#     'аквапарк в казань работа ривьера'],
#    300,
#    'работа в казани ривьера'],
#   [['банк казань работа', 'банк в казань работа', 'альфа банк казань работа'],
#    199,
#    'работа в казани банк'],
#   [['в казань от работа работодатель свежий',
#     'в казань от прямой работа работодатель свежий',
#     'авито казань от прямой работа работодатель свежий'],
#    291,
#    'работа в казани от'],
#   [['казань работа рынок',
#     'казань работа рынок центральный',
#     'вьетнамский казань работа рынок'],
#    115,
#    'работа в казани рынок'],
#   [['казань работа татарстан', 'в казань работа республика татарстан'],
#    124,
#    'работа в казани татарстан'],
#   [['казань находить работа', 'в казань находить работа'],
#    118,
#    'работа в казани находить'],
#   [['казань работа ру', 'казань работа хх', 'казань работа ру хх'],
#    116,
#    'работа в казани ру'],
#   [['в для женщина казань работа',
#     'для женщина казань работа свежий',
#     'в для женщина казань проживание работа с'],
#    85,
#    'работа в казани для'],
#   [['в для казань мужчина работа', 'в для казань мужчина проживание работа с'],
#    66,
#    'работа в казани для'],
#   [['дом казань на работа',
#     'казань машина на работа',
#     'казань на работа тэцевский',
#     'казань на работа устройство',
#     'казань медосмотр на работа',
#     'день казань на работа',
#     'в казань на работа устраиваться',
#     'в завод казань на работа',
#     'выполняться казань маневровый на почему работа станция'],
#    176,
#    'работа в казани дом'],
#   [['в казань магазин работа', 'казань магазин пятерочка работа'],
#    54,
#    'работа в казани магазин'],
#   [['казань официальный работа сайт', 'в казань работа сайт'],
#    75,
#    'работа в казани официальный'],
#   [['в искать казань работа',
#     'в казань каменщик работа',
#     'в искать казань каменщик работа'],
#    63,
#    'работа в казани искать'],
#   [['в казань отзыв работа',
#     'в казань пятерочка работа',
#     'казань отзыв пятерочка работа',
#     'в казань отзыв пятерочка работа сотрудник'],
#    75,
#    'работа в казани отзыв'],
#   [['казань работа ручной',
#     'казань обувь работа',
#     'казань обувь работа ручной'],
#    70,
#    'работа в казани ручной'],
#   [['в казань музей работа', '2020 август в в казань музей работа'],
#    48,
#    'работа в казани музей'],
#   [['казань кафе работа', 'казань кафе работа ресторан'],
#    45,
#    'работа в казани кафе'],
#   [['в казань компания работа', 'казань компания работа транспортный'],
#    40,
#    'работа в казани компания'],
#   [['в казань категория работа',
#     'в е казань категория работа',
#     'в д казань категория работа',
#     'авито е казань категория работа'],
#    70,
#    'работа в казани категория'],
#   [['бухгалтер в казань работа',
#     'бухгалтер казань мусульманка работа',
#     'в казань мусульманка работа'],
#    63,
#    'работа в казани бухгалтер'],
#   [['авито казань от работа работодатель',
#     'авито казань от прямой работа работодатель'],
#    50,
#    'работа в казани авито'],
#   [['в казань работа ресторан', 'в казань коронавирус работа ресторан'],
#    34,
#    'работа в казани ресторан'],
#   [['вахтовый казань работа', 'в вахтовый казань метод работа'],
#    36,
#    'работа в казани вахтовый'],
#   [['казань работа рынок тур', 'в казань работа тур'],
#    42,
#    'работа в казани рынок'],
#   [['казань работа сантехнический',
#     'казань прайс работа сантехнический',
#     'казань лист на прайс работа сантехнический'],
#    54,
#    'работа в казани сантехнический'],
#   [['в казань работа россия',
#     'казань почта работа россия',
#     'в казань почта работа'],
#    45,
#    'работа в казани россия'],
#   [['казань кырлай парк работа',
#     'горький казань парк работа',
#     'в казань парк работа',
#     'казань парк работа хауса'],
#    46,
#    'работа в казани кырлай'],
#   [['автомобиль казань на работа',
#     'в грузовой казань на работа',
#     'автомобиль грузовой казань на работа'],
#    29,
#    'работа в казани автомобиль'],
#   [['казань косметика работа',
#     'в казань магнит работа',
#     'казань косметика магнит работа'],
#    30,
#    'работа в казани косметика'],
#   [['казань приволжский работа район', 'казань московский работа район'],
#    21,
#    'работа в казани приволжский'],
#   [['ак барс казань работа', 'ак банк барс казань работа'],
#    23,
#    'работа в казани ак'],
#   [['автомаляр в казань работа', 'авито автомаляр казань работа'],
#    22,
#    'работа в казани автомаляр'],
#   [['казань отделочный работа'], 12, 'работа в казани отделочный'],
#   [['бухгалтер в казань работа ру'], 12, 'работа в казани бухгалтер'],
#   [['в для казань работа студент', 'в девушка для казань работа'],
#    17,
#    'работа в казани для'],
#   [['в жилье казань работа с',
#     'жилье казань предоставление работа с',
#     'в казань предоставление работа с'],
#    26,
#    'работа в казани жилье'],
#   [['в для иногородний казань проживание работа с'], 9, 'работа в казани для'],
#   [['в иногородний казань работа'], 9, 'работа в казани иногородний'],
#   [['в казань на отделочный прайс работа'], 7, 'работа в казани на']],
#  'казань работа вакансии': [[['вакансия казань погрузчик работа фронтальный',
#     'в вакансия казань мини на погрузчик работа'],
#    7,
#    'казань работа вакансии погрузчик'],
#   [['вакансия казань нн работа',
#     'вакансия город казань работа',
#     'вакансия казань няня работа',
#     'вакансия казань пятерочка работа',
#     'вакансия газета казань работа',
#     'вакансия казань просто работа',
#     '1000 вакансия казань работа',
#     'вакансия казань работа склад',
#     'вакансия иннополис казань работа',
#     'avito вакансия казань работа',
#     'вакансия казань озон работа',
#     'вакансия казань проживание работа с',
#     'аэропорт в вакансия казань работа',
#     'вакансия казань обучение работа с',
#     'wildberries в вакансия казань работа',
#     'в вакансия интернет казань работа',
#     'в вакансия казань мчс работа',
#     'архив в вакансия казань работа',
#     'библиотекарь в вакансия казань работа',
#     'в вакансия казань массажист работа',
#     'в вакансия казань работа суд',
#     'в вакансия казань работа сантехник',
#     'в вайлдберриз вакансия казань работа',
#     'вакансия казань медицинский работа сестра',
#     'в вакансия казань метро работа',
#     'в вакансия казань мегастрой работа',
#     'в вакансия казань мфц работа',
#     'в вакансия газпром казань работа',
#     'в вакансия казань работа сантехника',
#     'вакансия казань от прямой работа хх',
#     'в вакансия казань проводник работа ржд',
#     'в вакансия занятость казань работа центр',
#     'без в вакансия казань посредник работа'],
#    62,
#    'казань работа вакансии нн'],
#   [['бухгалтер вакансия казань работа',
#     'бухгалтер в вакансия казань работа свежий'],
#    8,
#    'казань работа вакансии бухгалтер'],
#   [['hh вакансия казань работа',
#     'ru вакансия казань работа',
#     'hh ru вакансия казань работа'],
#    7,
#    'казань работа вакансии hh'],
#   [['авито в вакансия казань на работа свежий',
#     'в вакансия казань на работа свежий сегодня'],
#    5,
#    'казань работа вакансии авито'],
#   [['вакансия икеа казань на работа',
#     'вакансия казань на обь работа',
#     'вакансия выходной казань на работа',
#     'в вакансия завод казань на работа',
#     'вакансия икеа казань на официальный работа сайт'],
#    13,
#    'казань работа вакансии икеа'],
#   [['банк вакансия казань работа', 'банк в вакансия казань работа'],
#    4,
#    'казань работа вакансии банк'],
#   [['в вакансия казань находить работа свежий',
#     'в вакансия казань работа ру свежий'],
#    3,
#    'казань работа вакансии в'],
#   [['авито вакансия казань работа ру', 'авито вакансия казань работа сегодня'],
#    3,
#    'казань работа вакансии авито'],
#   [['вакансия казань работа сиделка',
#     'в вакансия казань работа свежий сиделка'],
#    2,
#    'казань работа вакансии сиделка'],
#   [['hh вакансия казань работа свежий', 'hh ru вакансия казань работа свежий'],
#    2,
#    'казань работа вакансии hh']],
#  'вакансии работодателя казань': [[['вакансия валберис казань от прямой работодатель',
#     'вакансия казань от прямой работодатель уборщица',
#     'вакансия казань нн от прямой работодатель',
#     'вакансия казань от прямой работодатель сегодня',
#     'вакансия для женщина казань от прямой работодатель',
#     'в вакансия казань няня от прямой работодатель',
#     'в вакансия казань медсестра от прямой работодатель',
#     'в вакансия казань мерчендайзер от прямой работодатель',
#     'вакансия казань от проживание прямой работодатель с',
#     'в вакансия казань от прямой психолог работодатель',
#     'в вакансия казань от производство прямой работодатель',
#     'в вакансия казань от прямой работодатель руководитель'],
#    20,
#    'вакансии работодателя казань валберис'],
#   [['вакансия казань от прямой работодатель хедхантер',
#     'бухгалтер вакансия казань от прямой работодатель свежий',
#     'вакансия казань от прямой работодатель свежий хедхантер'],
#    10,
#    'вакансии работодателя казань от'],
#   [['администратор вакансия казань прямой работодатель'],
#    1,
#    'вакансии работодателя казань администратор']],
#  'авито работа казань': [[['авито казань работа ру',
#     'авито казань повар работа',
#     'авито казань работа упаковщица',
#     'авито июль казань работа',
#     'авито казань работа сегодня',
#     'авито казань официант работа',
#     'авито бухгалтер казань работа',
#     'авито для казань работа студент',
#     'авито в казань работа свежий',
#     '2 2 авито казань работа',
#     'авито высокий гора казань работа'],
#    25,
#    'авито работа казань ру'],
#   [['авито казань на работа фасовщица',
#     'авито казань на работа уборщица',
#     'авито в дальнобойщик казань на работа',
#     'авито в казань на находить работа',
#     'авито в искать казань на работа',
#     'авито в казань на от прямой работа'],
#    13,
#    'авито работа казань на']],
#  'авито казань вакансии': [[['авито вакансия казань сиделка',
#     'авито вакансия казань ру',
#     'авито вакансия казань сегодня',
#     'авито вакансия казань швея',
#     'авито вакансия для казань мужчина',
#     'авито в вакансия казань от прямой'],
#    9,
#    'авито казань вакансии сиделка']],
#  'свежие вакансии казань': [[['вакансия казань свежий хх',
#     'вакансия казань ру свежий хх'],
#    8,
#    'свежие вакансии казань хх'],
#   [['бухгалтер вакансия казань свежий',
#     'вакансия казань разнорабочий свежий',
#     'вакансия казань находить свежий',
#     'вакансия город казань свежий',
#     'hh вакансия казань свежий',
#     'вакансия вахтер казань свежий',
#     'вакансия казань руководитель свежий',
#     'hh ru вакансия казань свежий'],
#    14,
#    'свежие вакансии казань бухгалтер'],
#   [['вакансия вакансия казань свежий сегодня',
#     'вакансия вакансия казань свежий сиделка',
#     'администратор вакансия вакансия казань свежий',
#     'вакансия вакансия занятость казань свежий центр',
#     'в вакансия казань проживание с свежий сиделка'],
#    9,
#    'свежие вакансии казань сегодня']],
#  'работа казань свежие': [[['бухгалтер казань работа свежий',
#     'без казань работа свежий',
#     'казань работа свежий сегодня',
#     'hh казань работа свежий',
#     'в казань работа свежий уборщица',
#     'в казань медсестра работа свежий',
#     'в казань находить работа свежий',
#     'hh ru казань работа свежий',
#     'без казань посредник работа свежий сиделка'],
#    23,
#    'работа казань свежие бухгалтер'],
#   [['казань работа ру свежий хх', 'казань работа ру свежий ххра'],
#    5,
#    'работа казань свежие ру']],
#  'центр занятости казань': [[['занятость казань центр',
#     'занятость казань официальный центр',
#     'занятость казань сайт центр',
#     'г занятость казань центр',
#     'гагарин занятость казань центр',
#     'занятость казань труд центр',
#     'занятость казань официальный сайт центр',
#     '46 гагарин занятость казань центр',
#     'в занятость казань работа центр'],
#    151,
#    'центр занятости казань'],
#   [['занятость казань население центр',
#     'занятость казань телефон центр',
#     'город занятость казань центр',
#     'г занятость казань население центр',
#     'занятость казань население телефон центр',
#     'гку занятость казань население центр',
#     'вакансия занятость казань население центр',
#     'город занятость казань население центр',
#     'г гку занятость казань население центр'],
#    40,
#    'центр занятости казань население'],
#   [['занятость казань кировский центр',
#     'занятость казань кировский район центр',
#     'занятость казань кировский население центр',
#     'занятость казань кировский население район центр',
#     'занятость казань кировский район телефон центр',
#     'занятость казань кировский район сайт центр',
#     'г занятость казань кировский район центр'],
#    42,
#    'центр занятости казань кировский'],
#   [['занятость казань советский центр',
#     'занятость казань район советский центр',
#     'занятость казань население советский центр',
#     'г занятость казань район советский центр',
#     'занятость казань население район советский центр',
#     'занятость казань официальный район советский центр',
#     'занятость казань курсы район советский центр',
#     'занятость казань район советский труд центр',
#     'г занятость казань население район советский центр'],
#    51,
#    'центр занятости казань советский'],
#   [['занятость кабинет казань личный центр',
#     'занятость кабинет казань личный население центр'],
#    10,
#    'центр занятости казань кабинет'],
#   [['занятость казань новый савиновский центр',
#     'занятость казань новый район савиновский центр',
#     'вакансия занятость казань новый савиновский центр'],
#    16,
#    'центр занятости казань новый'],
#   [['занятость казань приволжский центр',
#     'занятость казань приволжский район центр',
#     'г занятость казань приволжский район центр',
#     'город занятость казань приволжский район центр'],
#    12,
#    'центр занятости казань приволжский'],
#   [['занятость казань московский центр',
#     'занятость казань московский район центр',
#     'занятость казань московский район телефон центр',
#     'вакансия занятость казань московский район центр'],
#    10,
#    'центр занятости казань московский'],
#   [['авиастроительный занятость казань центр',
#     'авиастроительный занятость казань район центр'],
#    4,
#    'центр занятости казань авиастроительный'],
#   [['занятость казань курсы центр',
#     '2020 занятость казань курсы центр',
#     'декретница для занятость казань курсы центр'],
#    4,
#    'центр занятости казань курсы'],
#   [['занятость интерактивный казань портал центр',
#     'занятость интерактивный казань население портал центр'],
#    2,
#    'центр занятости казань интерактивный']],
#  'работа сегодня казань': [[['в икеа казань работа сегодня',
#     'в казань работа сбербанк сегодня',
#     'казань оплата работа с сегодня',
#     'в для женщина казань работа сегодня'],
#    11,
#    'работа сегодня казань в']],
#  'работа казань банки': [[['банк казань почта работа',
#     'банк казань отзыв работа',
#     'банк казань отделение работа',
#     'банк казань отп работа',
#     'банк казань работа тимер'],
#    15,
#    'работа казань банки почта']],
#  'казань работа без': [[['без казань оформление работа',
#     'без казань посредник работа',
#     'без в казань образование работа',
#     'автомобиль без в казань личный работа',
#     'без в казань посредник работа сиделка',
#     'без в казань проживание работа сиделка',
#     'без день каждый казань оплата оформление работа'],
#    17,
#    'казань работа без оформление']],
#  'биржа труда казань': [[['биржа казань труд',
#     'биржа казань телефон труд',
#     'биржа казань московский труд',
#     'биржа казань официальный труд',
#     'биржа казань сайт труд',
#     'биржа вакансия казань труд',
#     'биржа казань советский труд',
#     'биржа казань московский район труд',
#     'биржа казань официальный сайт труд',
#     'биржа казань район советский труд',
#     'биржа документ казань какой труд'],
#    75,
#    'биржа труда казань'],
#   [['биржа казань новый савиновский труд',
#     'биржа казань новый район савиновский труд',
#     'биржа казань новый район савиновский телефон труд'],
#    18,
#    'биржа труда казань новый'],
#   [['биржа казань кировский труд',
#     'биржа казань кировский район труд',
#     'биржа казань кировский район телефон труд'],
#    9,
#    'биржа труда казань кировский'],
#   [['биржа казань как на становиться труд',
#     'биржа вставать госуслуга казань на труд через',
#     'биржа в вставать казань как на труд'],
#    6,
#    'биржа труда казань как'],
#   [['биржа казань приволжский труд',
#     'биржа казань приволжский район труд',
#     'биржа казань приволжский район телефон труд'],
#    5,
#    'биржа труда казань приволжский']],
#  'курсы трудоустройством казань': [],
#  'вакансии казань от прямых': [[['вакансия казань от прямой хх',
#     'вакансия казань от прямой хедхантер',
#     'вакансия казань медсестра от прямой',
#     'вакансия казань мерчендайзер от прямой',
#     'вакансия казань от проживание прямой с'],
#    12,
#    'вакансии казань от прямых хх']],
#  'работа от работодателей казань': [[['казань от прямой работа работодатель ру',
#     'казань от прямой работа работодатель хх',
#     'казань от прямой работа работодатель склад',
#     'казань медсестра от прямой работа работодатель',
#     'в казань няня от работа работодатель',
#     'hh казань от прямой работа работодатель',
#     'бухгалтер в казань от прямой работа работодатель',
#     'в казань от прямой работа работодатель слесарь',
#     'в казань няня от прямой работа работодатель',
#     'в казань от прямой работа работодатель юрист',
#     'в казань от поиск прямой работа работодатель'],
#    30,
#    'работа от работодателей казань прямой'],
#   [['казань напрямую от работа работодатель',
#     'в казань находить от работа работодатель',
#     'в казань напрямую находить от работа работодатель'],
#    7,
#    'работа от работодателей казань напрямую'],
#   [['казань находить прямой работа работодатель',
#     'в казань поиск работа работодатель'],
#    3,
#    'работа от работодателей казань находить']],
#  'работа казань прямой работодатель': [],
#  'работа в казани от прямых': [[['бухгалтер в казань от прямой работа',
#     'в казань от поиск прямой работа',
#     'в казань находить от прямой работа',
#     'в казань няня от прямой работа',
#     'в казань медсестра от прямой работа',
#     'в казань от прямой работа юрист'],
#    15,
#    'работа в казани от прямых бухгалтер'],
#   [['hh казань от прямой работа', 'hh ru казань от прямой работа'],
#    2,
#    'работа в казани от прямых hh']]}
